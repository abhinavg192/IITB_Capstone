# %% [markdown]
# <a href="https://colab.research.google.com/github/abhinavg192/IITB_Capstone/blob/main/notebooks/abhinav/abhinav_week1_langchain_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install required libraries
# !pip install langchain langchain-anthropic langchain-openai openai anthropic -q

from langchain_core.prompts import PromptTemplate
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 662.1/662.1 kB 17.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.4/542.4 kB 14.0 MB/s eta 0:00:00

# %%
# Load API keys securely from Colab Secrets
from google.colab import userdata

ANTHROPIC_API_KEY = userdata.get('ANTHROPIC_API_KEY')
OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')

# Quick check - confirms keys loaded without exposing them
print("Anthropic key loaded:", ANTHROPIC_API_KEY[:10] + "...")
print("OpenAI key loaded:", OPENAI_API_KEY[:10] + "...")
# Out:
# Anthropic key loaded: sk-ant-api...
# OpenAI key loaded: sk-proj-SP...

# %%
# First Claude API call using LangChain
from langchain_anthropic import ChatAnthropic
from langchain_core.messages import HumanMessage

# Initialize the Claude model
llm = ChatAnthropic(
    model="claude-haiku-4-5-20251001",
    api_key=ANTHROPIC_API_KEY,
    max_tokens=4000
)

# Send a simple test message
response = llm.invoke([HumanMessage(content="Write a short Twitter post about coffee.")])

print(response.content)
# Out:
# ☕ Nothing hits quite like that first sip of coffee in the morning. It's not just caffeine, it's a ritual, a moment of peace, and a reason to get out of bed. What's your go-to order?

# %%
linkedin_template = PromptTemplate(
    input_variables=["brand_name", "topic", "tone"],
    template="""
You are an expert social media content creator specializing in professional content.

Your task is to write 5 distinct LinkedIn post variants for the brand {brand_name}.

TOPIC: {topic}
TONE: {tone}

LINKEDIN RULES:
- 150 to 300 words per post
- Start with a strong hook — first line must stop the scroll
- Use professional but human language
- Break text into short paragraphs for readability
- End with a thought provoking question or clear call to action
- Use 3-5 relevant hashtags at the end
- No excessive emojis — maximum 2 per post

OUTPUT FORMAT:
Return exactly 5 posts numbered like this:
1. [post text]
[hashtags]

2. [post text]
[hashtags]

Write only the posts. No explanations.
"""
)

# %%
instagram_template = PromptTemplate(
    input_variables=["brand_name", "topic", "tone"],
    template="""
You are an expert social media content creator specializing in Instagram content.

Your task is to write 5 distinct Instagram caption variants for the brand {brand_name}.

TOPIC: {topic}
TONE: {tone}

INSTAGRAM RULES:
- Maximum 2200 characters per post
- First line MUST be a scroll-stopping hook — this is critical
- Use storytelling and lifestyle language
- Use emojis throughout to add personality
- Write in a warm, relatable, visual style
- Include a clear call to action before the hashtags
- Use 5-10 relevant hashtags at the end separated from the caption

OUTPUT FORMAT:
Return exactly 5 captions numbered like this:
1. [hook line]
[caption body]
[call to action]
[hashtags]

2. [hook line]
[caption body]
[call to action]
[hashtags]

Write only the captions. No explanations.
"""
)

# %%
from langchain_core.prompts import PromptTemplate

twitter_template = PromptTemplate(
    input_variables=["brand_name", "topic", "tone"],
    template="""
You are an expert social media content creator.

Your task is to write 5 distinct Twitter post variants for the brand {brand_name}.

TOPIC: {topic}
TONE: {tone}

TWITTER RULES:
- Maximum 280 characters per post
- Use 2-3 relevant hashtags per post
- Keep language punchy and direct
- Include a call to action where natural

OUTPUT FORMAT:
Return exactly 5 posts numbered like this:
1. [post text] [hashtags]
2. [post text] [hashtags]
3. [post text] [hashtags]
4. [post text] [hashtags]
5. [post text] [hashtags]

Write only the posts. No explanations.
"""
)

# %%
filled_prompt = twitter_template.format(
    brand_name="Adobe",
    topic="Adobe's acquisition of Semrush",
    tone="confident, forward looking, market leading — emphasize Adobe is stronger than ever"
)
response = llm.invoke([HumanMessage(content=filled_prompt)])
print("TWITTER POSTS:")
print(response.content)
# Out:
# TWITTER POSTS:
# 1. Game-changing move: Adobe + Semrush. We're combining creative excellence with SEO dominance to lead the digital marketing future. The best just got better. #AdobeAcquiresSemrush #MarketLeader #DigitalMarketing
#
# 2. Stronger together. Adobe's acquisition of Semrush means you get unmatched creative AND SEO tools in one platform. The future of marketing starts now. #AdobeInnovation #Semrush #MarketingTools
#
# 3. Adobe just raised the bar. We're acquiring Semrush to give creators & marketers the complete toolkit they need to win. One platform. Infinite possibilities. #AdobeLeads #DigitalTransformation
#
# 4. This is what market leadership looks like. Adobe + Semrush = unstoppable creative & marketing power. Your competitive advantage just arrived. #Adobe #Semrush #MarketingExcellence
#
# 5. We're not just acquiring Semrush—we're reshaping the industry. Adobe continues its mission to empower creators & marketers everywhere. The future is here. #AdobeFuture #Innovation #MarketingTech

# %%
filled_prompt = linkedin_template.format(
    brand_name="Adobe",
    topic="Adobe's acquisition of Semrush",
    tone="professional, strategic, reassuring to investors, forward looking"
)
response = llm.invoke([HumanMessage(content=filled_prompt)])
print("LINKEDIN POSTS:")
print(response.content)
# Out:
# LINKEDIN POSTS:
# 1. Adobe just made a bold move in the digital intelligence space—and it changes everything.
#
# The acquisition of Semrush represents far more than a transaction. It's a strategic convergence of creativity and data-driven decision-making.
#
# For years, Adobe has empowered creators and marketers to build exceptional digital experiences. Semrush has given them the visibility to understand what works. Together, we're creating a comprehensive ecosystem where creativity meets intelligence.
#
# This move strengthens Adobe's position across the entire customer journey—from content creation through performance measurement. Our customers gain unified insights within their existing workflows. No more switching between platforms. No more fragmented data.
#
# The market is consolidating around integrated solutions. Brands increasingly demand tools that not only help them create but also measure, optimize, and scale their impact. Semrush's industry-leading SEO, content, and competitive intelligence capabilities perfectly complement Creative Cloud and Experience Cloud.
#
# For investors, this acquisition demonstrates Adobe's commitment to expanding TAM while deepening customer relationships. Higher switching costs. Increased lifetime value. Sustainable competitive advantages.
#
# The future belongs to companies that understand the full picture—where analytics inform creativity, and creativity is validated by data.
#
# How are you currently bridging the gap between creative output and measurable business results?
#
# #Adobe #Semrush #DigitalStrategy #MarketConsolidation #CreativeIntelligence
#
# 2. We're witnessing a fundamental shift in how digital success is measured—and Adobe is leading it.
#
# Today's announcement of Adobe's acquisition of Semrush signals something critical: the end of siloed solutions. Modern organizations need visibility across their entire digital ecosystem.
#
# Semrush brings proven expertise in SEO, content marketing, competitive intelligence, and campaign management. Adobe brings the world's leading creative and analytics platforms. Combined, they create something genuinely transformative.
#
# Consider what this means:
#
# Marketing teams get real-time performance data integrated directly into their creative workflows. Content creators understand exactly what resonates with audiences. Business leaders gain comprehensive visibility into digital investments.
#
# This isn't just additive—it's multiplicative. It's about reducing friction in how teams work and decisions get made.
#
# For Adobe customers, integration becomes seamless. For Adobe shareholders, this represents significant revenue synergies and customer expansion opportunities. The TAM expands dramatically when solutions work together rather than in isolation.
#
# The competitive landscape is clear: platforms win. Point solutions lose.
#
# What's your current biggest pain point in connecting creative execution with measurable business outcomes?
#
# #Adobe #Semrush #DigitalTransformation #PlatformStrategy #MarketingTech
#
# 3. Strategic acquisitions reveal where the market is headed. Adobe's acquisition of Semrush? It's a masterclass in forward-thinking positioning.
#
# For Adobe customers, this is fundamentally good news. Here's why:
#
# The digital marketing landscape has fragmented across dozens of specialized tools. Teams juggle creative platforms, analytics solutions, SEO tools, and competitive intelligence separately. This creates inefficiency, data silos, and missed opportunities.
#
# Semrush solves for visibility. Adobe solves for creation. Together, they solve for business impact.
#
# This acquisition reflects several important truths about where digital strategy is evolving:
#
# **Integration is non-negotiable.** Customers are tired of switching between platforms.
#
# **Data drives creativity.** The best creative work is informed by deep audience insights.
#
# **Measurement justifies investment.** Marketing budgets increasingly demand ROI clarity.
#
# By bringing Semrush into the Adobe family, we're not just acquiring capabilities—we're acquiring a talented team and millions of satisfied customers who understand the value of intelligent digital insights.
#
# The integration work ahead will create compounding advantages. What starts as separate products becomes an interconnected intelligence network.
#
# Which marketing challenges could be solved if your creative and analytics tools actually talked to each other?
#
# #Adobe #Semrush #DigitalMarketing #TechIntegration #CustomerSuccess
#
# 4. Adobe's acquisition of Semrush isn't about size—it's about strategic completeness.
#
# In today's digital economy, competitive advantage flows to companies with comprehensive intelligence. Adobe recognized an opportunity to build something more complete, more powerful, and more valuable.
#
# Semrush brings:
# - Industry-leading SEO and competitive intelligence
# - Trusted by millions of digital professionals
# - Proven monetization and growth trajectory
# - Deep expertise in content and campaign optimization
#
# Adobe brings:
# - Market-leading creative tools trusted by billions
# - Enterprise-grade analytics and customer data platforms
# - Global scale and investment capacity
# - Commitment to platform integration
#
# The strategic logic is compelling. Digital success increasingly requires visibility into what works before, during, and after content goes live. Semrush provides that intelligence. Adobe provides the tools to act on it.
#
# For shareholders, this acquisition demonstrates disciplined capital allocation toward high-growth, high-margin segments. Marketing intelligence is a multi-billion dollar market with significant tailwinds. Adobe is positioned to capture disproportionate share.
#
# For customers, this signals unwavering commitment to solving real problems in modern marketing and digital creation.
#
# The best tools aren't the ones that do one thing perfectly. They're the ones that work seamlessly with everything else.
#
# How could unified creative and intelligence platforms change your competitive position?
#
# #Adobe #Semrush #StrategicAcquisition #DigitalIntelligence #CustomerValue
#
# 5. Adobe + Semrush: What happens when the world's leading creative platform meets the world's most trusted digital intelligence platform?
#
# You get an unfair advantage.
#
# This acquisition isn't defensive—it's expansive. Adobe isn't buying Semrush to protect against competition. Adobe is buying Semrush because the market increasingly demands integrated solutions that simultaneously fuel creativity and drive measurable results.
#
# Think about how digital professionals actually work:
#
# They create remarkable content. Then they wonder: What will resonate? How will it perform? What should we create next?
#
# Those questions require intelligence. Real intelligence. Competitive intelligence. Audience intelligence. Performance intelligence.
#
# Historically, this intelligence lived in separate platforms. Not anymore.
#
# Semrush's proven track record with SEO professionals, content marketers, and competitive researchers gives Adobe direct access to millions of professionals who've already validated the value of comprehensive digital intelligence.
#
# This creates a clear path to expansion—introducing these customers to Creative Cloud and Experience Cloud. Meanwhile, Adobe's existing customer base gains access to world-class SEO, content, and competitive insights without leaving their workflow.
#
# The financial trajectory is also compelling: increased wallet share, higher customer LTV, significant operational synergies, and a stronger defensible moat.
#
# What would become possible if you had real-time competitive and audience intelligence integrated directly into your creative process?
#
# #Adobe #Semrush #DigitalMarketing #PlatformIntegration #InvestorNews

# %%
filled_prompt = instagram_template.format(
    brand_name="Adobe",
    topic="CEO Shantanu Narayen announcing retirement after 17 years of leadership",
    tone="warm, celebratory, human — honor the legacy while exciting the community about Adobe's bold future ahead"
)
response = llm.invoke([HumanMessage(content=filled_prompt)])
print("INSTAGRAM POSTS:")
print(response.content)
# Out:
# INSTAGRAM POSTS:
# 1. 17 years. One visionary. Infinite possibilities ahead. 🎨
#
# Today, we celebrate Shantanu Narayen—the leader who transformed Adobe into a creative powerhouse. 🚀
#
# Since 2007, Shantanu has guided us through digital revolutions, market shifts, and moments that redefined what's possible. He didn't just lead a company; he championed creators everywhere. From cloud innovations to AI breakthroughs, his fingerprints are on every chapter of our story. 💙
#
# But here's the beautiful part: this isn't an ending. It's a passing of the torch. ✨ Shantanu's legacy lives in every creator using our tools, every innovation in our pipeline, and the bold culture he built.
#
# As we step into our next chapter, we're carrying forward his belief that technology should empower human creativity—not replace it.
#
# What's your favorite Adobe memory? Drop it in the comments to celebrate the impact of visionary leadership. 👇
#
# #AdobeFamily #ShantanuNarayen #CreativeLeadership #NewBeginnings #AdobeInnovation #CreativeIndustry #TechLeadership #FutureOfCreativity
#
# 2. The greatest leaders know when to pass the baton—and Shantanu Narayen just did it beautifully. 🎬
#
# Seventeen years. That's how long one person shaped the dreams of millions of creators worldwide. 🌍
#
# Shantanu didn't just run Adobe—he reimagined it. He believed in a world where creative tools could be democratized, where cloud technology could liberate designers, and where AI could amplify (not diminish) human imagination. And he built it. 🛠️
#
# From Photoshop to Firefly, from humble beginnings to a $200B+ market cap, his journey inspires everyone who dares to dream big. 💡
#
# The creativity doesn't stop here. Our community keeps growing. Our tools keep evolving. And the next chapter? It's going to be legendary. 🚀
#
# Tell us: What will YOU create next? Share your next project idea below! ⬇️
#
# #AdobeCommunity #Leadership #CreativeTools #Retirement #NewChapter #CreativeProfessionals #AdobeCreative #TechInnovation #FutureIsNow
#
# 3. Some leaders change companies. Shantanu Narayen changed an entire creative industry. 🎨✨
#
# After 17 transformative years at the helm, our visionary CEO is stepping into his next adventure—and we're overflowing with gratitude and excitement. 💚
#
# What made Shantanu legendary wasn't just strategic brilliance (though he had plenty). It was his unwavering belief that every creator deserves world-class tools. He turned that belief into reality. From portfolio professionals to aspiring TikTokers, from indie designers to Fortune 500 studios—Adobe's reach expanded because he dared to dream bigger. 🌟
#
# His leadership showed us that success isn't measured in quarters alone. It's measured in the work people create, the dreams they achieve, and the industries they reshape. 🚀
#
# The torch passes. The mission continues. The best part? You—our creative community—are writing what comes next.
#
# Share a moment where Adobe tools helped you create something you're proud of. Your stories matter. 👇💙
#
# #AdobeLeadership #CreativeEmpowerment #TechInnovation #NewEra #ShantanuNarayen #AdobeFamily #CreativeTools #DesignCommunity #FutureOfCreativity #Inspired
#
# 4. A 17-year love letter to visionary leadership—and a promise of what's coming. 💌🎬
#
# Today we say thank you to Shantanu Narayen, whose leadership transformed Adobe into a creative sanctuary for millions worldwide. 🌈
#
# When Shantanu took the helm, he had a simple but radical vision: What if technology could amplify human creativity instead of complicating it? What if artists, designers, filmmakers, and creators could focus on their craft instead of fighting their tools? He didn't just ask these questions—he answered them. Beautifully. 🎨✨
#
# Seventeen years later, Adobe is synonymous with creative freedom. Photoshop isn't just software—it's a language. Premiere Pro isn't just an editor—it's a storyteller's best friend. And Firefly? It's the future Shantanu believed in. 🚀
#
# As we celebrate his incredible journey, we're equally thrilled about what's ahead. The same visionary spirit that got us here? It lives in our team, our community, and our commitment to you.
#
# What has Adobe helped you create? Show us your masterpiece in the comments! 👇🎉
#
# #AdobeStory #CreativeLeadership #Gratitude #NewBeginnings #CreativeTools #AdobeInnovation #DesignCommunity #Storytelling #FutureOfCreativity #AdobeFamily
#
# 5. When a leader steps back, a community steps forward. That's Shantanu's greatest legacy. 🌟
#
# Seventeen years. One person. Millions of creations inspired. 🎨
#
# Shantanu Narayen built something rare: a company where technology serves the artist, not the other way around. He believed that the best innovations happen when you listen to creators—really listen—and then build tools that feel like extensions of their imagination. 💡✨
#
# Through market challenges, industry shifts, and technological revolutions, Shantanu remained steady: focused on empowering creativity, building community, and thinking decades ahead. 🚀 That's visionary leadership in its truest form.
#
# But here's what excites us most: Shantanu's fingerprints are everywhere in Adobe's DNA now. His philosophy lives in every product update, every creator we support, every innovation we pursue. The torch passes, but the flame burns brighter. 🔥💙
#
# You're the next chapter of this story. What will you create? Share your dreams and projects below—we're cheering you on! 👇
#
# #AdobeLeadership #CreativeJourney #VisionaryLeader #AdobeFamily #CreativeTools #NewChapter #TechInnovation #DesignCommunity #FutureIsCreative #Inspired

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("thedevastator/tweets-and-user-engagement")

print("Path to dataset files:", path)
# Out:
# Downloading to /root/.cache/kagglehub/datasets/thedevastator/tweets-and-user-engagement/2.archive...
# 100%|██████████| 8.70M/8.70M [00:00<00:00, 79.7MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/thedevastator/tweets-and-user-engagement/versions/2

# %%
import requests

github_file_url = "YOUR_GITHUB_RAW_URL_HERE" # Replace with the raw URL of your dataset file on GitHub

# Extract filename from URL
filename = github_file_url.split('/')[-1]

try:
    response = requests.get(github_file_url)
    response.raise_for_status() # Raise an exception for HTTP errors

    with open(filename, 'wb') as f:
        f.write(response.content)

    print(f"Dataset '{filename}' downloaded successfully!")
except requests.exceptions.RequestException as e:
    print(f"Error downloading file: {e}")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Error downloading file: Invalid URL 'YOUR_GITHUB_RAW_URL_HERE': No scheme supplied. Perhaps you meant https://YOUR_GITHUB_RAW_URL_HERE?

# %%
import os

# Paste your token value here between the quotes
KAGGLE_TOKEN = "KGAT_bb4ee1763840e8cec48410422b69e997"

# Set up the environment variable
os.environ['KAGGLE_API_TOKEN'] = KAGGLE_TOKEN

# Install kaggle
# !pip install kaggle -q

print("Kaggle setup done!")
# Out:
# Kaggle setup done!

# %%
# Download the dataset
# !kaggle datasets download -d thedevastator/tweets-and-user-engagement --unzip

# Check what got downloaded
import os
print(os.listdir('.'))
# Out:
# Dataset URL: https://www.kaggle.com/datasets/thedevastator/tweets-and-user-engagement
# License(s): other
# Downloading tweets-and-user-engagement.zip to /content
# 100% 8.70M/8.70M [00:00<00:00, 219MB/s]
#
# ['.config', 'Twitterdatainsheets.csv', 'sample_data']

# %% [markdown]
# For good few-shot examples we want posts from 3-4 different brand styles:
#
# | Style | Example Brand | Why |
# | -------- | -------- | -------- |
# | Consumer/Lifestyle | Starbucks, Nike | Casual, emotional, visual |
# | B2B/Tech | AWS, Adobe | Professional, feature-focused |
# | News/Corporate | BBC, Reuters | Informational, factual |
# | Startup/Energetic | Spotify, Duolingo | Fun, bold, personality-driven |

# %% [markdown]
# # Few-Shot Examples for Social Media Agent
# ## Collected: May 2026 | Sources: Nike (Twitter), Adobe (LinkedIn), National Geographic (Instagram)
#
# ---
#
# ## Twitter Examples (Source: @Nike)
#
# **Example 1 — Athlete/Event Celebration:**
# "When you're this fast, you don't ask for permission.
# Jutta Leerdam breaks the Olympic record in the Speed Skating 1000m
# and wins her first Gold. #MilanoCortina2026 #Olympics"
#
# **Example 2 — Product Launch:**
# "Mute the gallery. Introducing Nike Powerbeats Pro 2, the ultimate
# fitness earbuds. The first-ever Beats x Nike collab — where premium
# sound meets unbeatable stability. No advice required.
# Launching March 20th at 9am PST at apple.com, nike.com,
# and select Apple stores globally."
#
# **Example 3 — Motivational/Quote:**
# "There's no failure in sports. It's steps to success." - @Giannis_An34
# Regardless of the outcome, there's always a reward ahead.
# #AlwaysForward"
#
# ---
#
# ## LinkedIn Examples (Source: Adobe)
#
# **Example 1 — Thought Leadership/Research:**
# "Creative teams are under pressure to deliver more content across
# more channels than ever before. Many are turning to AI to handle
# production tasks like resizing, versioning, and early-stage ideation,
# so they can spend more time refining concepts and craft.
# Adobe's latest research breaks down how this shift is changing
# the way we do creative work.
# Learn more: https://adobe.ly/3QJAEcK"
#
# **Example 2 — Corporate Announcement:**
# "The way brands are discovered is changing fast. Today, Adobe
# completed its acquisition of Semrush, expanding how businesses
# show up, get found, and drive growth in an AI-first world.
# The shift is already here. AI-driven traffic to U.S. retail sites
# is up 269% year over year, yet most businesses still have significant
# gaps in how they appear across AI surfaces. Visibility is no longer
# just about ranking. It is about relevance, presence, and performance
# across every surface where decisions are made.
# Together, as part of Adobe CX Enterprise, Adobe and Semrush are
# helping businesses close that gap across SEO, generative engine
# optimization (GEO), and agentic search optimization (ASO), with
# deeper insights, stronger intelligence, and more connected customer
# experiences. We look forward to welcoming Semrush team members
# into Adobe. We can't wait to build what's next, together."
#
# **Example 3 — Community/Human Story:**
# "My greatest inspiration came from being raised by a self-made
# single mom who showed us strength and resilience."
# From drawing at a young age to now utilizing Adobe tools to bridge
# the gap between art and business, Alexandra Yvette continues to
# create and share her talents with the world this Women's History Month."
#
# ---
#
# ## Instagram Examples (Source: @NatGeo)
#
# **Example 1 — Wildlife/Action Story:**
# "This image was taken near Polán, Toledo province (Spain) last August
# (2025), from a tiny hide-out overlooking a small waterhole where
# lynxes occasionally come down to drink. It was an extremely hot
# afternoon, and a rabbit was very close to the water. Suddenly, a lynx
# appeared silently, but the rabbit noticed it at the very last second.
# In a desperate attempt to escape, it launched itself into the water
# and then made an incredible leap over the lynx's paw. I couldn't
# believe what I was witnessing. For a brief moment, the rabbit actually
# escaped, and then the chase began. It lasted only a couple of minutes,
# but it felt endless. I've been photographing Iberian lynxes for more
# than five years, and this was the first time in my life I was able to
# witness and document a complete hunting sequence.
# Photo by @alexandrovich_yo from our @natgeoyourshot community."
#
# **Example 2 — Landscape/Philosophical:**
# "From Punta Helbronner, 11,370 feet (3,466 meters) above sea level
# on the Italian side of Mont Blanc in the Alps, my guide walks out
# across the snow toward Dent du Géant, the Giant's Tooth, illuminated
# only by the light of my drone during a long exposure.
# In images like this, I'm interested in how a small change in the light
# can shift the scale of a landscape, briefly turning a lone figure into
# a point of orientation within something far larger and older.
# In the blue hour, the mountain held its shape with a seemingly
# absolute stillness, while that moving light traced a human presence
# across the snow for just a few seconds.
# Photos by @reuben"
#
# **Example 3 — Milestone/Achievement:**
# "Barcelona's Sagrada Família has reached a new milestone. With the
# cross now installed atop its central Jesus tower, the basilica stands
# more than 560 feet (170m) — surpassing Germany's Ulm Minster as
# the world's tallest church. Discover how architects used modern tools
# and building techniques to bring Antoni Gaudí's original design to
# life more than 140 years after he began construction at the link in bio.
# Photographs by Nuria Puentes, National Geographic-España"
#
# ---
#
# ## Summary Table
#
# | Platform | Example 1 | Example 2 | Example 3 |
# |---|---|---|---|
# | Twitter | Athlete/Event | Product Launch | Motivational Quote |
# | LinkedIn | Thought Leadership | Corporate Announcement | Human Story |
# | Instagram | Wildlife Drama | Landscape Poetry | Milestone/Achievement |
#
# ## Why These Examples Were Chosen
# - **Variety of formats** — each example covers a different post type
# - **Real posts from real brands** — not fabricated, actual published content
# - **High engagement posts** — sourced from top brand pages
# - **Platform appropriate** — tone, length and structure match each platform's norms
# - **Text stands alone** — captions work without needing to see the image
#
# ---
# *Note: For future iterations, automate example selection by pulling
# top performing posts from brand analytics APIs ranked by real
# engagement data.*

# %%
# Few-shot examples for each platform
twitter_examples = """
EXAMPLE 1 (Athlete/Event Celebration - Nike):
"When you're this fast, you don't ask for permission. Jutta Leerdam
breaks the Olympic record in the Speed Skating 1000m and wins her
first Gold. #MilanoCortina2026 #Olympics"

EXAMPLE 2 (Product Launch - Nike):
"Mute the gallery. Introducing Nike Powerbeats Pro 2, the ultimate
fitness earbuds. The first-ever Beats x Nike collab — where premium
sound meets unbeatable stability. No advice required.
Launching March 20th at 9am PST."

EXAMPLE 3 (Motivational/Quote - Nike):
"There's no failure in sports. It's steps to success." - @Giannis_An34
Regardless of the outcome, there's always a reward ahead. #AlwaysForward
"""

linkedin_examples = """
EXAMPLE 1 (Thought Leadership - Adobe):
"Creative teams are under pressure to deliver more content across more
channels than ever before. Many are turning to AI to handle production
tasks like resizing, versioning, and early-stage ideation, so they can
spend more time refining concepts and craft. Adobe's latest research
breaks down how this shift is changing the way we do creative work."

EXAMPLE 2 (Corporate Announcement - Adobe):
"The way brands are discovered is changing fast. Today, Adobe completed
its acquisition of Semrush, expanding how businesses show up, get found,
and drive growth in an AI-first world. The shift is already here.
AI-driven traffic to U.S. retail sites is up 269% year over year, yet
most businesses still have significant gaps in how they appear across
AI surfaces. Visibility is no longer just about ranking. It is about
relevance, presence, and performance across every surface where
decisions are made."

EXAMPLE 3 (Community/Human Story - Adobe):
"My greatest inspiration came from being raised by a self-made single
mom who showed us strength and resilience. From drawing at a young age
to now utilizing Adobe tools to bridge the gap between art and business,
Alexandra Yvette continues to create and share her talents with the
world this Women's History Month."
"""

instagram_examples = """
EXAMPLE 1 (Wildlife/Action Story - NatGeo):
"This image was taken near Polán, Toledo province (Spain) last August,
from a tiny hide-out overlooking a small waterhole where lynxes
occasionally come down to drink. It was an extremely hot afternoon,
and a rabbit was very close to the water. Suddenly, a lynx appeared
silently, but the rabbit noticed it at the very last second. In a
desperate attempt to escape, it launched itself into the water and
then made an incredible leap over the lynx's paw. I couldn't believe
what I was witnessing. For a brief moment, the rabbit actually escaped,
and then the chase began. I've been photographing Iberian lynxes for
more than five years, and this was the first time I was able to witness
and document a complete hunting sequence.
Photo by @alexandrovich_yo from our @natgeoyourshot community."

EXAMPLE 2 (Landscape/Philosophical - NatGeo):
"From Punta Helbronner, 11,370 feet above sea level on the Italian
side of Mont Blanc in the Alps, my guide walks out across the snow
toward Dent du Géant, the Giant's Tooth, illuminated only by the
light of my drone during a long exposure. In images like this, I'm
interested in how a small change in the light can shift the scale of
a landscape, briefly turning a lone figure into a point of orientation
within something far larger and older. In the blue hour, the mountain
held its shape with a seemingly absolute stillness, while that moving
light traced a human presence across the snow for just a few seconds.
Photos by @reuben"

EXAMPLE 3 (Milestone/Achievement - NatGeo):
"Barcelona's Sagrada Família has reached a new milestone. With the
cross now installed atop its central Jesus tower, the basilica stands
more than 560 feet (170m) — surpassing Germany's Ulm Minster as the
world's tallest church. Discover how architects used modern tools and
building techniques to bring Antoni Gaudí's original design to life
more than 140 years after he began construction.
Photographs by Nuria Puentes, National Geographic-España"
"""

print("✅ Few-shot examples loaded!")
# Out:
# ✅ Few-shot examples loaded!

# %%
from langchain_core.prompts import PromptTemplate

# Twitter Few-Shot Template
twitter_fewshot_template = PromptTemplate(
    input_variables=["brand_name", "topic", "tone"],
    template="""
You are an expert social media content creator.

Your task is to write 5 distinct Twitter post variants for the brand {brand_name}.

TOPIC: {topic}
TONE: {tone}

TWITTER RULES:
- Maximum 280 characters per post
- Use 2-3 relevant hashtags per post
- Keep language punchy and direct
- Include a call to action where natural

HERE ARE EXAMPLES OF HIGH PERFORMING TWITTER POSTS:
""" + twitter_examples + """

Now write 5 posts matching the same quality and style as the examples above.

OUTPUT FORMAT:
1. [post text] [hashtags]
2. [post text] [hashtags]
3. [post text] [hashtags]
4. [post text] [hashtags]
5. [post text] [hashtags]

Write only the posts. No explanations.
"""
)

# LinkedIn Few-Shot Template
linkedin_fewshot_template = PromptTemplate(
    input_variables=["brand_name", "topic", "tone"],
    template="""
You are an expert social media content creator specializing in professional content.

Your task is to write 5 distinct LinkedIn post variants for the brand {brand_name}.

TOPIC: {topic}
TONE: {tone}

LINKEDIN RULES:
- 150 to 300 words per post
- Start with a strong hook — first line must stop the scroll
- Use professional but human language
- Break text into short paragraphs for readability
- End with a thought provoking question or clear call to action
- Use 3-5 relevant hashtags at the end
- No excessive emojis — maximum 2 per post

HERE ARE EXAMPLES OF HIGH PERFORMING LINKEDIN POSTS:
""" + linkedin_examples + """

Now write 5 posts matching the same quality and style as the examples above.

OUTPUT FORMAT:
1. [post text]
[hashtags]

2. [post text]
[hashtags]

Write only the posts. No explanations.
"""
)

# Instagram Few-Shot Template
instagram_fewshot_template = PromptTemplate(
    input_variables=["brand_name", "topic", "tone"],
    template="""
You are an expert social media content creator specializing in Instagram content.

Your task is to write 5 distinct Instagram caption variants for the brand {brand_name}.

TOPIC: {topic}
TONE: {tone}

INSTAGRAM RULES:
- Maximum 2200 characters per post
- First line MUST be a scroll-stopping hook
- Use storytelling and lifestyle language
- Use emojis throughout to add personality
- Write in a warm, relatable, visual style
- Include a clear call to action before the hashtags
- Use 5-10 relevant hashtags at the end

HERE ARE EXAMPLES OF HIGH PERFORMING INSTAGRAM CAPTIONS:
""" + instagram_examples + """

Now write 5 captions matching the same quality and style as the examples above.

OUTPUT FORMAT:
1. [hook line]
[caption body]
[call to action]
[hashtags]

2. [hook line]
[caption body]
[call to action]
[hashtags]

Write only the captions. No explanations.
"""
)

print("✅ Few-shot templates loaded for all 3 platforms!")
# Out:
# ✅ Few-shot templates loaded for all 3 platforms!

# %%
# Test all 3 few-shot templates with the same topic
test_topic = "Adobe's acquisition of Semrush"
test_brand = "Adobe"

# Twitter
twitter_filled = twitter_fewshot_template.format(
    brand_name=test_brand,
    topic=test_topic,
    tone="confident, forward looking, market leading"
)
twitter_response = llm.invoke([HumanMessage(content=twitter_filled)])
print("=" * 50)
print("TWITTER POSTS:")
print("=" * 50)
print(twitter_response.content)

# LinkedIn
linkedin_filled = linkedin_fewshot_template.format(
    brand_name=test_brand,
    topic=test_topic,
    tone="professional, strategic, reassuring to investors, forward looking"
)
linkedin_response = llm.invoke([HumanMessage(content=linkedin_filled)])
print("\n" + "=" * 50)
print("LINKEDIN POSTS:")
print("=" * 50)
print(linkedin_response.content)

# Instagram
instagram_filled = instagram_fewshot_template.format(
    brand_name=test_brand,
    topic=test_topic,
    tone="warm, celebratory, innovative, inspiring"
)
instagram_response = llm.invoke([HumanMessage(content=instagram_filled)])
print("\n" + "=" * 50)
print("INSTAGRAM POSTS:")
print("=" * 50)
print(instagram_response.content)
# Out:
# ==================================================
# TWITTER POSTS:
# ==================================================
# 1. Adobe + Semrush = unstoppable. We're combining the world's leading creative platform with the most powerful marketing intelligence engine. The future of digital marketing just got a major upgrade. #AdobeSemrush #MarketLeadership
#
# 2. When creativity meets data, magic happens. Adobe acquires Semrush to unlock next-level insights for creators and marketers everywhere. Your competitive edge just arrived. #AdobeLife #DigitalMarketing #FutureOfWork
#
# 3. We're not just acquiring Semrush—we're redefining what's possible. Creative excellence + competitive intelligence = the platform every marketer needs. Welcome to the next era. #AdobeAcquiresSemrush #CreativeIntelligence
#
# 4. Your creative work deserves intelligent strategy behind it. Adobe + Semrush brings SEO, content, and competitive insights directly into your workflow. Elevate your game today. #AdobeSemrush #SmartCreativity #MarketIntelligence
#
# 5. One platform. Unlimited potential. Adobe's acquisition of Semrush means creators and marketers can finally do it all—create brilliantly AND compete fearlessly. The industry just changed. #AdobeForward #DigitalTransformation
#
# ==================================================
# LINKEDIN POSTS:
# ==================================================
# 1. The future of marketing just shifted. Today, Adobe completed its acquisition of Semrush, bringing together two industry leaders to reshape how businesses compete in an AI-driven world.
#
# For years, marketers have juggled fragmented tools—content creation, SEO insights, performance analytics—across disconnected platforms. That era is ending. This acquisition unites Adobe's creative and document intelligence with Semrush's market-leading visibility and competitive intelligence tools.
#
# The result? A unified platform where strategy meets execution. Teams can now research opportunities, create optimized content, and measure impact—all within one intelligent ecosystem.
#
# For investors and stakeholders, this is clear: Adobe is doubling down on the entire customer journey, not just creative tools. We're building the operating system for modern marketing.
#
# What does your team spend the most time switching between different platforms for each month?
#
# #AdobeAcquisition #MarketingTechnology #DigitalTransformation #StrategicGrowth #AdobeSemrush
#
# ---
#
# 2. Visibility without strategy is just noise. Strategy without visibility is a missed opportunity.
#
# That's why today matters. Adobe's acquisition of Semrush closes a critical gap in how businesses understand their market and execute their growth plans. In an AI-first world, competitive intelligence and creative excellence must work together.
#
# Semrush brings unmatched insights into market trends, competitor movements, and audience behavior. Adobe brings the creative firepower and AI innovation to act on those insights at scale. Together, we're enabling businesses to move faster than ever—from insight to impact.
#
# For stakeholders watching digital transformation unfold: this is Adobe strengthening its competitive moat in the enterprise. We're not just expanding our footprint; we're deepening our relevance where businesses make their biggest decisions.
#
# The question isn't whether to integrate these capabilities—it's whether you can afford not to.
#
# How is fragmented tooling impacting your team's ability to execute quickly?
#
# #AdobeNews #MarketIntelligence #CreativeStrategy #DigitalGrowth #SemrushAcquisition
#
# ---
#
# 3. The best strategies are built on insight. The best execution is built on creativity. Until now, these lived in separate worlds.
#
# Adobe's acquisition of Semrush changes that. We're bringing together market intelligence and creative excellence—two capabilities that every growth-focused business needs, but few have truly integrated.
#
# Semrush's competitive research, SEO expertise, and market visibility tools are now part of the Adobe ecosystem. This means marketing teams can go deeper on strategy and faster on execution. Product teams can understand market gaps before competitors do. Enterprise leaders can make decisions backed by both data and creative possibility.
#
# The integration is strategic, thoughtful, and built for scale. We're not combining tools—we're unifying how businesses think about growth.
#
# For investors and partners: Adobe is systematically building the most comprehensive platform for digital-first enterprises. Each acquisition strengthens our ability to deliver end-to-end solutions that matter.
#
# What's the biggest bottleneck between your strategy and execution today?
#
# #AdobeInnovation #MarketIntelligence #StrategicAcquisition #CreativeStrategy #GrowthPlatform
#
# ---
#
# 4. Every competitive advantage starts with knowing what's possible.
#
# Today, Adobe acquired Semrush—and with it, we're fundamentally changing how businesses understand their market, reach their audience, and measure what matters. This isn't about adding another tool to the stack. It's about reimagining how teams work.
#
# For creative professionals: You'll have deeper market insights to inform your work. For marketers: You'll move from intuition to intelligence, backed by AI-powered recommendations. For enterprises: You'll have visibility across the entire customer journey—from discovery to decision.
#
# The digital landscape is moving faster than ever. Businesses that thrive will be those that can synthesize insight, create at scale, and adapt in real time. Adobe + Semrush delivers exactly that.
#
# Our commitment to investors is simple: we're building infrastructure that becomes more valuable as AI advances, not less.
#
# What capabilities do you wish your current tools could do together?
#
# #AdobeSemrush #DigitalTransformation #MarketingInnovation #EnterpriseGrowth #AIEnabled
#
# ---
#
# 5. The companies winning today aren't choosing between data and creativity. They're mastering both.
#
# Adobe's acquisition of Semrush is our answer to that reality. We're bringing together two trusted platforms—one that understands markets, one that transforms ideas into impact—into a single, intelligent ecosystem.
#
# Semrush has earned the trust of millions of marketers and businesses worldwide. That expertise, combined with Adobe's creative and AI capabilities, creates something new: a complete platform for growth in an AI-first world.
#
# This is strategic alignment at scale. It's about recognizing that modern businesses need market visibility AND creative excellence. They need competitive intelligence AND rapid execution. They need data that informs AND creativity that inspires.
#
# For stakeholders evaluating Adobe's direction: We're investing in breadth and depth simultaneously. We're not chasing trends—we're building the infrastructure that defines how work gets done.
#
# How do you currently bridge the gap between market insight and creative execution?
#
# #AdobeAcquisition #MarketingStack #DigitalStrategy #CreativeIntelligence #FutureOfWork
#
# ==================================================
# INSTAGRAM POSTS:
# ==================================================
# 1. When two creative powerhouses join forces, magic happens. ✨
#
# Today, we're thrilled to announce that Adobe is welcoming Semrush into our family—and we couldn't be more excited about what's next. 🚀
#
# For years, creators, marketers, and businesses have relied on Adobe to bring their visions to life through design, video, and storytelling. Now, by combining Adobe's creative excellence with Semrush's industry-leading SEO and content intelligence tools, we're creating something unprecedented: a complete ecosystem where your creativity meets strategy, where your art finds its audience, and where data-driven insights fuel your boldest ideas. 🎨📊
#
# This isn't just an acquisition—it's a celebration of what happens when innovation meets intention. When the tools you use to create are seamlessly connected to the insights that amplify your work. Imagine designing a campaign in Creative Cloud and instantly understanding how to optimize it for maximum impact. Imagine creating content that's not just beautiful, but brilliantly strategic. That's the future we're building together. 💡
#
# We're honoring everything Semrush has built while weaving their expertise into the Adobe experience you love. Better tools. Deeper insights. Unlimited possibilities.
#
# Ready to create your next breakthrough? Explore how Adobe + Semrush is reshaping what's possible for creators everywhere.
#
# #AdobeAcquiresSemrush #CreativeInnovation #TheFutureOfMarketing #DesignMeetsStrategy #CreatorsUnited #AdobeFamily #DigitalTransformation #ContentCreation #MarketingInnovation #CreativeTools
#
# 2. One platform. Infinite possibilities. Here's how we just changed the game. 🎯
#
# We're announcing something that's been in the making for months, and today we finally get to share it with you: Adobe has acquired Semrush, and the creative world will never be the same. 🌟
#
# Think about your creative journey. You start with an idea. You design it beautifully using Adobe's tools—whether that's Photoshop, Premiere Pro, or any of our incredible creative suite. But then comes the next question: "How do I make sure the right people see this?" That gap—the space between creation and strategy—is exactly what we're closing today.
#
# Semrush's world-class SEO, content intelligence, and competitive insights are now becoming part of the Adobe ecosystem. This means creators and marketers can stay in one unified platform, where every design decision is informed by real data, where every campaign is optimized before it even launches, where your creativity is amplified by strategy at every step. 🚀✨
#
# We're not just adding features. We're reimagining what it means to create with purpose. What it means to design with confidence. What it means to build work that doesn't just look good—it *performs* brilliantly.
#
# Join us in celebrating this moment. Discover how the future of creative work starts here.
#
# #AdobeSemrushAcquisition #CreativeRevolution #DesignInnovation #MarketingTools #FutureOfCreativity #AdobeCreativeCloud #ContentStrategy #SeamlessIntegration #CreatorEconomy #SmartCreative
#
# 3. Behind every great creative achievement, there's a story of connection. Today, we're starting a new one. 📖✨
#
# Adobe just acquired Semrush, and it's a moment that celebrates everything we believe in: the power of bringing the right tools together at the right time.
#
# For creators and marketers navigating today's digital landscape, the journey has always required juggling multiple platforms. You'd design something extraordinary in Adobe, then leap to different tools to understand its reach, its impact, its potential. It was brilliant work happening in silos. But what if it didn't have to be that way?
#
# By bringing Semrush's market-leading intelligence into Adobe's creative ecosystem, we're creating a new kind of creative confidence. The kind where you know, the moment you finish designing, that your work is already optimized for success. Where data informs artistry. Where strategy and creativity aren't opposing forces—they're partners in creation. 🎨📈
#
# This acquisition is about recognizing that today's creators aren't just artists or marketers—they're strategic thinkers who want the freedom to create brilliantly *and* the insight to amplify their impact. Semrush's trusted tools, combined with Adobe's creative excellence, make that possible.
#
# We're not just announcing an acquisition. We're inviting you into a movement where your creative vision meets its full potential.
#
# Explore the possibilities waiting for you in this new chapter.
#
# #AdobeAcquiresSemrush #CreativeStrategy #FutureOfDesign #MarketingIntelligence #AdobeInnovation #CreativeTools #DataDrivenCreativity #ContentOptimization #CreatorCommunity #DesignWithPurpose
#
# 4. What happens when creative power meets strategic intelligence? Everything changes. 🌟
#
# Today, Adobe welcomes Semrush to our family, and we're celebrating a moment that could only happen when two industry leaders decide to build the future together. 💪
#
# For the past decade-plus, Semrush has been helping millions of marketers, creators, and businesses understand the digital landscape with precision and clarity. Meanwhile, Adobe has been empowering creators to imagine bigger, design bolder, and share their visions with the world. Separately, they've been incredible. Together? They're unstoppable. 🚀
#
# This acquisition represents a fundamental shift in how creative work gets done. Imagine a world where your creative process is never disconnected from strategic insight. Where the moment you finish a design, you understand its competitive landscape. Where optimization isn't a separate step—it's woven into the fabric of creation itself. That's what we're building. 🎨✨
#
# Semrush's world-class platform for content marketing, SEO, and competitive insights is joining Adobe's legendary Creative Cloud. The result? A unified ecosystem where creators and marketers can finally operate from a place of complete confidence—knowing their work is not just beautiful, but strategically brilliant. 📊
#
# This is about honoring the vision that both Adobe and Semrush have cultivated while creating something that's bigger than both of us. It's about the future of creative work—and you're invited to be part of it.
#
# Discover what's possible when creativity meets strategy. Join us.
#
# #AdobeSemrush #CreativeEcosystem #InnovationInAction #MarketingEvolution #DesignStrategy #CreativeIntelligence #FutureOfWork #AdobeFamily #ContentMarketing #UnifiedPlatform
#
# 5. Sometimes the best ideas come from bringing the best teams together. Today is one of those days. 🎉
#
# Adobe has acquired Semrush, and this moment marks something special: a celebration of collaboration, innovation, and endless creative potential. 💫
#
# Every creator has experienced that moment of wondering: "Is this working? Who's seeing it? How can I make it even better?" That curiosity—that desire to create with both artistry *and* intelligence—is what inspired this acquisition. Because the tools you use to create should be seamlessly connected to the insights that help you grow. 🚀
#
# Semrush has spent years mastering competitive intelligence, content strategy, and SEO—helping creators understand the digital landscape with unmatched precision. Adobe has spent decades empowering the world's most creative minds to bring their visions to life through design, video, and storytelling. Together, we're creating something revolutionary: a platform where creativity and strategy aren't separate journeys—they're one beautiful, integrated experience. 🎨📈
#
# Think of it this way. You design something amazing. Instantly, you have the insights to optimize it. You create content. Immediately, you understand its potential. You build campaigns with confidence because you're armed with both artistry and intelligence. That's the future we're creating for every creator, marketer, and visionary out there. ✨
#
# This is more than an acquisition—it's a promise to the creative community that we're committed to giving you everything you need to succeed, all in one place.
#
# Step into the future of creative work with Adobe and Semrush.
#
# #AdobeAcquiresSemrush #CreativeEmpowerment #MarketingInnovation #DesignIntelligence #AdobeFamily #CreatorTools #StrategicCreativity #ContentSuccess #FutureReady #OneEcosystem

# %%
from langchain_core.prompts import PromptTemplate
import json

json_template = PromptTemplate(
    input_variables=["brand_name", "topic", "tone", "platform"],
    template="""
You are an expert social media content creator.

Generate exactly 5 distinct social media post variants for the brand {brand_name}.

PLATFORM: {platform}
TOPIC: {topic}
TONE: {tone}

PLATFORM RULES:
- Twitter: maximum 280 characters, 2-3 hashtags, punchy and direct
- LinkedIn: 150-300 words, professional but human, 3-5 hashtags
- Instagram: storytelling style, 5-10 hashtags, strong opening hook

IMPORTANT: You must respond with ONLY a valid JSON array.
No explanations. No preamble. No markdown. Just the JSON.

Return exactly this structure:
[
  {{
    "variant_id": 1,
    "post_text": "the post content here",
    "hashtags": ["#hashtag1", "#hashtag2"],
    "tone": "describe the tone used",
    "suggested_posting_time": "best day and time to post",
    "platform": "{platform}"
  }},
  {{
    "variant_id": 2,
    "post_text": "the post content here",
    "hashtags": ["#hashtag1", "#hashtag2"],
    "tone": "describe the tone used",
    "suggested_posting_time": "best day and time to post",
    "platform": "{platform}"
  }},
  {{
    "variant_id": 3,
    "post_text": "the post content here",
    "hashtags": ["#hashtag1", "#hashtag2"],
    "tone": "describe the tone used",
    "suggested_posting_time": "best day and time to post",
    "platform": "{platform}"
  }},
  {{
    "variant_id": 4,
    "post_text": "the post content here",
    "hashtags": ["#hashtag1", "#hashtag2"],
    "tone": "describe the tone used",
    "suggested_posting_time": "best day and time to post",
    "platform": "{platform}"
  }},
  {{
    "variant_id": 5,
    "post_text": "the post content here",
    "hashtags": ["#hashtag1", "#hashtag2"],
    "tone": "describe the tone used",
    "suggested_posting_time": "best day and time to post",
    "platform": "{platform}"
  }}
]
"""
)

print("✅ JSON template loaded!")
# Out:
# ✅ JSON template loaded!

# %%
# Generate 5 variants as structured JSON
filled_json_prompt = json_template.format(
    brand_name="Adobe",
    topic="Adobe's acquisition of Semrush",
    tone="professional, strategic, reassuring to investors",
    platform="linkedin"
)

# Call Claude
response = llm.invoke([HumanMessage(content=filled_json_prompt)])

# Parse the JSON response
try:
    # Clean the response in case Claude adds any extra text
    response_text = response.content.strip()

    # Remove markdown code blocks if Claude adds them
    if response_text.startswith("```"):
        response_text = response_text.split("```")[1]
        if response_text.startswith("json"):
            response_text = response_text[4:]

    # Parse into Python list
    variants = json.loads(response_text)

    print("✅ JSON parsed successfully!")
    print(f"Number of variants: {len(variants)}")
    print("\n--- VARIANT 1 PREVIEW ---")
    print(f"Post text: {variants[0]['post_text'][:100]}...")
    print(f"Hashtags: {variants[0]['hashtags']}")
    print(f"Tone: {variants[0]['tone']}")
    print(f"Posting time: {variants[0]['suggested_posting_time']}")
    print(f"Platform: {variants[0]['platform']}")

except json.JSONDecodeError as e:
    print(f"❌ JSON parsing failed: {e}")
    print("Raw response:")
    print(response.content)
# Out:
# ✅ JSON parsed successfully!
# Number of variants: 5
#
# --- VARIANT 1 PREVIEW ---
# Post text: We're excited to announce Adobe's acquisition of Semrush, a leading digital visibility platform. Thi...
# Hashtags: ['#AdobeAcquisition', '#DigitalTransformation', '#StrategicGrowth', '#InvestorNews']
# Tone: professional, strategic, confident
# Posting time: Tuesday 8:00 AM
# Platform: linkedin

# %%
# Print all 5 variants cleanly
for i, variant in enumerate(variants, 1):
    print(f"{'='*50}")
    print(f"VARIANT {i}")
    print(f"{'='*50}")
    print(f"Post Text:\n{variant['post_text']}")
    print(f"\nHashtags: {' '.join(variant['hashtags'])}")
    print(f"Tone: {variant['tone']}")
    print(f"Suggested Posting Time: {variant['suggested_posting_time']}")
    print(f"Platform: {variant['platform']}")
    print()
# Out:
# ==================================================
# VARIANT 1
# ==================================================
# Post Text:
# We're excited to announce Adobe's acquisition of Semrush, a leading digital visibility platform. This strategic move strengthens our ability to deliver comprehensive solutions for marketing and creative professionals worldwide. By combining Adobe's creative excellence with Semrush's market intelligence capabilities, we're positioned to unlock new value for customers and drive sustainable growth. This acquisition reflects our commitment to innovation and our confidence in the evolving digital landscape. We look forward to welcoming the talented Semrush team to Adobe.
#
# Hashtags: #AdobeAcquisition #DigitalTransformation #StrategicGrowth #InvestorNews
# Tone: professional, strategic, confident
# Suggested Posting Time: Tuesday 8:00 AM
# Platform: linkedin
#
# ==================================================
# VARIANT 2
# ==================================================
# Post Text:
# Strategic acquisitions drive innovation. We're pleased to share that Adobe is acquiring Semrush, expanding our digital ecosystem and strengthening our market position. This move enables us to offer integrated solutions that address the full spectrum of customer needs—from creative production to market analytics. Our investors can be confident that this acquisition is built on solid fundamentals: complementary technologies, proven market demand, and a talented workforce. Together, Adobe and Semrush will create meaningful value in an increasingly competitive landscape.
#
# Hashtags: #AdobeSemrush #MarketLeadership #CorporateStrategy #ShareholderValue
# Tone: reassuring, analytical, investor-focused
# Suggested Posting Time: Wednesday 9:30 AM
# Platform: linkedin
#
# ==================================================
# VARIANT 3
# ==================================================
# Post Text:
# Semrush joins Adobe. We're thrilled to announce this acquisition, which brings together two industry leaders committed to empowering businesses. Semrush's expertise in SEO, content marketing, and competitive intelligence complements Adobe's creative and collaboration tools perfectly. This integration positions us to serve customers more comprehensively while maintaining our unwavering focus on innovation and excellence. For our stakeholders, this represents a calculated investment in future growth and market expansion. We remain committed to delivering shareholder value through strategic, thoughtful acquisitions.
#
# Hashtags: #AdobeNews #SEO #MarketingTech #CorporateGrowth #Innovation
# Tone: professional, enthusiastic, stakeholder-focused
# Suggested Posting Time: Thursday 10:00 AM
# Platform: linkedin
#
# ==================================================
# VARIANT 4
# ==================================================
# Post Text:
# Announcing Adobe's acquisition of Semrush—a strategic investment in our future. This partnership amplifies our capabilities across creative, marketing, and business intelligence domains. Both companies share a vision of empowering professionals with best-in-class tools. From an investor perspective, this acquisition addresses clear market opportunities, diversifies our revenue streams, and enhances our competitive moat. The financial fundamentals are sound, the strategic rationale is clear, and the integration roadmap is solid. We're confident this move will create substantial long-term value.
#
# Hashtags: #AdobeStrategy #Acquisition #BusinessGrowth #InvestorRelations
# Tone: professional, reassuring, financially-minded
# Suggested Posting Time: Tuesday 2:00 PM
# Platform: linkedin
#
# ==================================================
# VARIANT 5
# ==================================================
# Post Text:
# Adobe acquires Semrush: expanding our vision for the future. This strategic acquisition unites two companies dedicated to digital excellence and customer success. Semrush brings proven market leadership in SEO and marketing analytics, while Adobe brings scale, resources, and a commitment to innovation. Our combined platform will deliver unprecedented value to customers globally. Investors should view this as a carefully considered move that strengthens our strategic positioning, broadens our addressable market, and reinforces our trajectory of sustainable, profitable growth.
#
# Hashtags: #AdobeAcquisition #DigitalMarketing #StrategicPartnership #FutureReady
# Tone: professional, optimistic, investor-reassuring
# Suggested Posting Time: Wednesday 11:00 AM
# Platform: linkedin

# %%
cot_json_template = PromptTemplate(
    input_variables=["brand_name", "topic", "tone", "platform"],
    template="""
You are an expert social media content creator.

Generate exactly 5 distinct social media post variants for the brand {brand_name}.

PLATFORM: {platform}
TOPIC: {topic}
TONE: {tone}

PLATFORM RULES:
- Twitter: maximum 280 characters, 2-3 hashtags, punchy and direct
- LinkedIn: 150-300 words, professional but human, 3-5 hashtags
- Instagram: storytelling style, 5-10 hashtags, strong opening hook

THINK STEP BY STEP BEFORE WRITING EACH VARIANT:
Step 1 - Audience: Who is the primary audience for this variant?
Step 2 - Key Message: What is the single most important message?
Step 3 - Tone Check: Does the tone match the brand and platform?
Step 4 - Hook: What opening line will stop the scroll?
Step 5 - CTA: What action should the reader take?
Then write the post based on your reasoning.

Make each variant structurally distinct:
- Variant 1: Lead with the business impact
- Variant 2: Lead with the customer benefit
- Variant 3: Lead with a bold statement or question
- Variant 4: Lead with data or proof points
- Variant 5: Lead with a human/emotional angle

IMPORTANT: Respond with ONLY a valid JSON array.
No explanations. No preamble. No markdown. Just the JSON.

Return exactly this structure:
[
  {{
    "variant_id": 1,
    "reasoning": "brief explanation of your thinking for this variant",
    "post_text": "the post content here",
    "hashtags": ["#hashtag1", "#hashtag2"],
    "tone": "describe the tone used",
    "suggested_posting_time": "best day and time to post",
    "platform": "{platform}"
  }},
  {{
    "variant_id": 2,
    "reasoning": "brief explanation of your thinking for this variant",
    "post_text": "the post content here",
    "hashtags": ["#hashtag1", "#hashtag2"],
    "tone": "describe the tone used",
    "suggested_posting_time": "best day and time to post",
    "platform": "{platform}"
  }},
  {{
    "variant_id": 3,
    "reasoning": "brief explanation of your thinking for this variant",
    "post_text": "the post content here",
    "hashtags": ["#hashtag1", "#hashtag2"],
    "tone": "describe the tone used",
    "suggested_posting_time": "best day and time to post",
    "platform": "{platform}"
  }},
  {{
    "variant_id": 4,
    "reasoning": "brief explanation of your thinking for this variant",
    "post_text": "the post content here",
    "hashtags": ["#hashtag1", "#hashtag2"],
    "tone": "describe the tone used",
    "suggested_posting_time": "best day and time to post",
    "platform": "{platform}"
  }},
  {{
    "variant_id": 5,
    "reasoning": "brief explanation of your thinking for this variant",
    "post_text": "the post content here",
    "hashtags": ["#hashtag1", "#hashtag2"],
    "tone": "describe the tone used",
    "suggested_posting_time": "best day and time to post",
    "platform": "{platform}"
  }}
]
"""
)

print("✅ Chain-of-thought JSON template loaded!")
# Out:
# ✅ Chain-of-thought JSON template loaded!

# %%
# Test chain-of-thought template
filled_cot_prompt = cot_json_template.format(
    brand_name="Adobe",
    topic="Adobe's acquisition of Semrush",
    tone="professional, strategic, reassuring to investors",
    platform="linkedin"
)

# Call Claude
response = llm.invoke([HumanMessage(content=filled_cot_prompt)])

# Parse JSON
try:
    response_text = response.content.strip()

    if response_text.startswith("```"):
        response_text = response_text.split("```")[1]
        if response_text.startswith("json"):
            response_text = response_text[4:]

    cot_variants = json.loads(response_text)

    print("✅ COT JSON parsed successfully!")
    print(f"Number of variants: {len(cot_variants)}")
    print()

    for i, variant in enumerate(cot_variants, 1):
        print(f"{'='*50}")
        print(f"VARIANT {i}")
        print(f"{'='*50}")
        print(f"Reasoning: {variant['reasoning']}")
        print(f"\nPost Text:\n{variant['post_text']}")
        print(f"\nHashtags: {' '.join(variant['hashtags'])}")
        print(f"Tone: {variant['tone']}")
        print(f"Posting Time: {variant['suggested_posting_time']}")
        print()

except json.JSONDecodeError as e:
    print(f"❌ JSON parsing failed: {e}")
    print("Raw response:")
    print(response.content)
# Out:
# ✅ COT JSON parsed successfully!
# Number of variants: 5
#
# ==================================================
# VARIANT 1
# ==================================================
# Reasoning: Audience: Institutional investors and financial analysts. Key Message: Strategic expansion strengthens market position. Tone Check: Confidence mixed with measured professionalism. Hook: Direct statement of acquisition significance. CTA: Implicit trust-building through transparency.
#
# Post Text:
# We're excited to announce Adobe's acquisition of Semrush, a transformative move that strengthens our position in the digital experience and marketing solutions space. This strategic partnership enables us to deliver integrated, end-to-end solutions for our customers while expanding our total addressable market. By combining Adobe's creative and document expertise with Semrush's industry-leading SEO and content marketing capabilities, we're creating unprecedented value for businesses of all sizes. This acquisition reflects our commitment to innovation and customer success in an increasingly competitive digital landscape. Our combined capabilities will drive revenue synergies and reinforce Adobe's leadership trajectory. We're confident this move positions us for sustained growth and shareholder value creation.
#
# Hashtags: #AdobeAcquisition #DigitalTransformation #StrategicGrowth #MarketLeadership #InvestorConfidence
# Tone: Professional, confident, reassuring with strategic business focus
# Posting Time: Tuesday 10:00 AM EST
#
# ==================================================
# VARIANT 2
# ==================================================
# Reasoning: Audience: Customers and creative professionals. Key Message: Enhanced capabilities directly benefit users. Tone Check: Human and supportive while remaining professional. Hook: Customer-centric benefit statement. CTA: Encourages exploration of expanded offerings.
#
# Post Text:
# Our customers asked for more integrated solutions, and we listened. Adobe's acquisition of Semrush means you'll soon have access to comprehensive marketing and SEO tools seamlessly integrated with your favorite creative and productivity applications. Imagine streamlining your entire content strategy—from creation to optimization to performance tracking—all within a unified Adobe ecosystem. This acquisition eliminates workflow friction and empowers teams to collaborate more effectively across creative, marketing, and analytics functions. We're committed to ensuring a smooth integration that respects your existing workflows while opening new possibilities for growth. Your success is our priority, and this strategic move demonstrates our dedication to providing the most powerful, integrated tools available in the industry.
#
# Hashtags: #CustomerSuccess #AdobeIntegration #ContentMarketing #CreativeTools #DigitalSolutions
# Tone: Human, supportive, customer-centric with professional reassurance
# Posting Time: Wednesday 9:00 AM EST
#
# ==================================================
# VARIANT 3
# ==================================================
# Reasoning: Audience: Industry observers and competitive analysts. Key Message: Game-changing strategic move. Tone Check: Bold but grounded in reality. Hook: Thought-provoking question that captures attention. CTA: Encourages engagement and discussion.
#
# Post Text:
# What happens when creative excellence meets marketing intelligence? Today, we're answering that question with Adobe's acquisition of Semrush. This isn't just another acquisition—it represents a fundamental shift in how businesses can approach integrated digital strategy. By uniting Adobe's world-class creative and document solutions with Semrush's marketing analytics and SEO expertise, we're creating a competitive advantage that's difficult to replicate. This move reflects a strategic evolution in how companies must think about the digital experience ecosystem. We're building the platform that empowers organizations to create, market, and measure success all in one place. The implications for our industry are significant, and we're thrilled to lead this transformation. What does this mean for the future of digital marketing? Join the conversation.
#
# Hashtags: #DigitalInnovation #MarketingTech #StrategicVision #IndustryShift #AdobeFuture
# Tone: Bold, visionary, strategic with professional curiosity
# Posting Time: Tuesday 2:00 PM EST
#
# ==================================================
# VARIANT 4
# ==================================================
# Reasoning: Audience: Data-driven investors and financial professionals. Key Message: Quantifiable benefits and market expansion. Tone Check: Evidence-based confidence. Hook: Concrete numbers demonstrating impact. CTA: Reinforces investor confidence through transparency.
#
# Post Text:
# By the numbers: Adobe's acquisition of Semrush positions us to serve a significantly expanded addressable market while delivering clear financial benefits. Semrush's 8+ million users across marketing, content, and competitive intelligence represent a substantial customer base with high engagement and strong retention. The integration unlocks immediate cross-sell opportunities—Adobe's 25 million+ creative and document users can now access premium marketing analytics, while Semrush's community gains access to industry-leading creative tools. This acquisition is projected to drive meaningful revenue synergies while enhancing our overall growth trajectory. The combined platform strengthens our competitive moat in an increasingly integrated digital solutions market. We're executing a disciplined, data-driven strategy that maximizes shareholder value while positioning Adobe as the essential platform for digital experience creation and optimization.
#
# Hashtags: #AdobeEarnings #BusinessStrategy #MarketExpansion #FinancialGrowth #Shareholders
# Tone: Data-driven, analytical, confident with quantifiable reassurance
# Posting Time: Wednesday 8:30 AM EST
#
# ==================================================
# VARIANT 5
# ==================================================
# Reasoning: Audience: Adobe employees, community, and culture-conscious investors. Key Message: Shared purpose and complementary teams. Tone Check: Inspirational yet grounded. Hook: Emotional connection to mission and values. CTA: Invite stakeholders into the journey.
#
# Post Text:
# Great products come from great people with shared vision. That's why we're thrilled to welcome the talented Semrush team to the Adobe family. This acquisition represents more than a business transaction—it's the convergence of two passionate communities committed to empowering digital professionals worldwide. Semrush's founders and team have built something remarkable by consistently listening to their users and innovating fearlessly. Those values align perfectly with Adobe's DNA. Together, we're not just combining capabilities; we're uniting two cultures dedicated to making digital work better for everyone. This journey will require thoughtful integration and open communication, and we're committed to honoring the culture and contributions that make Semrush special. We're building the future of digital experience together, and we can't wait to see what our combined teams will create.
#
# Hashtags: #AdobeTeam #CulturalFit #TalentAndCulture #DevelopingTogether #FutureOfWork
# Tone: Inspirational, human-centered, inclusive with authentic leadership voice
# Posting Time: Thursday 10:00 AM EST

# %%
# Validate JSON consistency across all 3 platforms
platforms = ["twitter", "linkedin", "instagram"]
results = {}

for platform in platforms:
    print(f"Testing {platform.upper()}...")

    filled_prompt = cot_json_template.format(
        brand_name="Adobe",
        topic="Adobe's acquisition of Semrush",
        tone="professional, strategic, forward looking",
        platform=platform
    )

    response = llm.invoke([HumanMessage(content=filled_prompt)])

    try:
        response_text = response.content.strip()

        if response_text.startswith("```"):
            response_text = response_text.split("```")[1]
            if response_text.startswith("json"):
                response_text = response_text[4:]

        variants = json.loads(response_text)
        results[platform] = variants

        print(f"✅ {platform.upper()} — {len(variants)} variants parsed successfully")
        print(f"   Variant 1 preview: {variants[0]['post_text'][:80]}...")
        print()

    except json.JSONDecodeError as e:
        print(f"❌ {platform.upper()} — JSON parsing failed: {e}")
        print()

print("="*50)
print(f"SUMMARY: {len(results)}/3 platforms working")
# Out:
# Testing TWITTER...
# ✅ TWITTER — 5 variants parsed successfully
#    Variant 1 preview: We're acquiring Semrush to strengthen our digital experience portfolio. This str...
#
# Testing LINKEDIN...
# ✅ LINKEDIN — 5 variants parsed successfully
#    Variant 1 preview: We're excited to announce Adobe's acquisition of Semrush, a transformative move ...
#
# Testing INSTAGRAM...
# ✅ INSTAGRAM — 5 variants parsed successfully
#    Variant 1 preview: We're expanding our creative and marketing ecosystem. Adobe has acquired Semrush...
#
# ==================================================
# SUMMARY: 3/3 platforms working
