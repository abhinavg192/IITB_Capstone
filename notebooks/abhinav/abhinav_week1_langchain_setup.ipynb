# %% [markdown]
# <a href="https://colab.research.google.com/github/abhinavg192/IITB_Capstone/blob/main/notebooks/abhinav/abhinav_week1_langchain_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install required libraries
# !pip install langchain langchain-anthropic langchain-openai openai anthropic -q

from langchain_core.prompts import PromptTemplate

# %%
# Load API keys securely from Colab Secrets
from google.colab import userdata

ANTHROPIC_API_KEY = userdata.get('ANTHROPIC_API_KEY')
OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')

# Quick check - confirms keys loaded without exposing them
print("Anthropic key loaded:", ANTHROPIC_API_KEY[:10] + "...")
print("OpenAI key loaded:", OPENAI_API_KEY[:10] + "...")
# Out:
# Anthropic key loaded: sk-ant-api...
# OpenAI key loaded: sk-proj-SP...

# %%
# First Claude API call using LangChain
from langchain_anthropic import ChatAnthropic
from langchain_core.messages import HumanMessage

# Initialize the Claude model
llm = ChatAnthropic(
    model="claude-haiku-4-5-20251001",
    api_key=ANTHROPIC_API_KEY,
    max_tokens=4000
)

# Send a simple test message
response = llm.invoke([HumanMessage(content="Write a short Twitter post about coffee.")])

print(response.content)
# Out:
# ☕ Nothing hits quite like that first sip of coffee in the morning—it's not just caffeine, it's a moment of peace before chaos takes over. What's your go-to order? #CoffeeAddict #MondayMotivation

# %%
linkedin_template = PromptTemplate(
    input_variables=["brand_name", "topic", "tone"],
    template="""
You are an expert social media content creator specializing in professional content.

Your task is to write 5 distinct LinkedIn post variants for the brand {brand_name}.

TOPIC: {topic}
TONE: {tone}

LINKEDIN RULES:
- 150 to 300 words per post
- Start with a strong hook — first line must stop the scroll
- Use professional but human language
- Break text into short paragraphs for readability
- End with a thought provoking question or clear call to action
- Use 3-5 relevant hashtags at the end
- No excessive emojis — maximum 2 per post

OUTPUT FORMAT:
Return exactly 5 posts numbered like this:
1. [post text]
[hashtags]

2. [post text]
[hashtags]

Write only the posts. No explanations.
"""
)

# %%
instagram_template = PromptTemplate(
    input_variables=["brand_name", "topic", "tone"],
    template="""
You are an expert social media content creator specializing in Instagram content.

Your task is to write 5 distinct Instagram caption variants for the brand {brand_name}.

TOPIC: {topic}
TONE: {tone}

INSTAGRAM RULES:
- Maximum 2200 characters per post
- First line MUST be a scroll-stopping hook — this is critical
- Use storytelling and lifestyle language
- Use emojis throughout to add personality
- Write in a warm, relatable, visual style
- Include a clear call to action before the hashtags
- Use 5-10 relevant hashtags at the end separated from the caption

OUTPUT FORMAT:
Return exactly 5 captions numbered like this:
1. [hook line]
[caption body]
[call to action]
[hashtags]

2. [hook line]
[caption body]
[call to action]
[hashtags]

Write only the captions. No explanations.
"""
)

# %%
from langchain_core.prompts import PromptTemplate

twitter_template = PromptTemplate(
    input_variables=["brand_name", "topic", "tone"],
    template="""
You are an expert social media content creator.

Your task is to write 5 distinct Twitter post variants for the brand {brand_name}.

TOPIC: {topic}
TONE: {tone}

TWITTER RULES:
- Maximum 280 characters per post
- Use 2-3 relevant hashtags per post
- Keep language punchy and direct
- Include a call to action where natural

OUTPUT FORMAT:
Return exactly 5 posts numbered like this:
1. [post text] [hashtags]
2. [post text] [hashtags]
3. [post text] [hashtags]
4. [post text] [hashtags]
5. [post text] [hashtags]

Write only the posts. No explanations.
"""
)

# %%
filled_prompt = twitter_template.format(
    brand_name="Adobe",
    topic="Adobe's acquisition of Semrush",
    tone="confident, forward looking, market leading — emphasize Adobe is stronger than ever"
)
response = llm.invoke([HumanMessage(content=filled_prompt)])
print("TWITTER POSTS:")
print(response.content)
# Out:
# TWITTER POSTS:
# 1. Adobe + Semrush = unstoppable. We're combining world-class creative tools with SEO intelligence. The future of digital marketing just got stronger. #Adobe #Semrush #Innovation
#
# 2. Today we're redefining what's possible. Semrush joins Adobe to accelerate how brands create, measure, and optimize. Stronger together. #AdobeAcquiresSemrush #MarketLeader
#
# 3. Semrush is now part of the Adobe family. Watch us transform how creators and marketers build their success—faster and smarter than ever. #Adobe #Semrush #FutureIsNow
#
# 4. Two powerhouses. One vision. Adobe acquires Semrush to deliver end-to-end solutions that help you create impact at scale. Join us forward. #Adobe #DigitalMarketing #NextLevel
#
# 5. We're not just acquiring Semrush—we're amplifying our mission. Adobe continues leading the industry with tools that inspire creativity and drive results. #Adobe #Semrush #CreativeCloud

# %%
filled_prompt = linkedin_template.format(
    brand_name="Adobe",
    topic="Adobe's acquisition of Semrush",
    tone="professional, strategic, reassuring to investors, forward looking"
)
response = llm.invoke([HumanMessage(content=filled_prompt)])
print("LINKEDIN POSTS:")
print(response.content)
# Out:
# LINKEDIN POSTS:
# 1. Adobe just doubled down on digital intelligence.
#
# Today we're announcing the acquisition of Semrush — a move that fundamentally reshapes how brands understand, create, and optimize their digital presence. This isn't just about adding tools to our portfolio. It's about closing a critical gap.
#
# For years, creative professionals have excelled at building exceptional content. But measuring impact across the full customer journey? That's been fragmented. With Semrush's industry-leading SEO, content, and competitive intelligence platform, we're creating an end-to-end solution that lets marketers see the complete picture.
#
# What does this mean for you?
#
# **For creatives:** Your designs and content will be informed by real market intelligence from day one.
#
# **For marketers:** You'll optimize campaigns with data that actually drives revenue, not just vanity metrics.
#
# **For investors:** We're entering a $30B+ market opportunity where integrated solutions command premium valuations.
#
# This acquisition accelerates our strategic vision: helping customers compete and win in an increasingly complex digital landscape. We're not just acquiring technology — we're investing in the future of integrated marketing.
#
# The best part? We're just getting started.
#
# What does your ideal marketing tech stack look like?
#
# #Adobe #Semrush #MarketingTechnology #DigitalTransformation #StrategicAcquisition
#
# 2. Here's what happens when creative excellence meets market intelligence.
#
# Adobe's acquisition of Semrush represents a watershed moment for the marketing technology industry. We're bringing together two complementary powerhouses: best-in-class creative tools and market-leading digital analytics and insights.
#
# The strategic rationale is straightforward but transformative:
#
# **Creatives need data.** Not to replace intuition, but to amplify it. Semrush's competitive intelligence and SEO insights give designers and marketers the context they need to create work that resonates.
#
# **Marketers need creativity at scale.** Adobe's suite enables teams to produce stunning content faster than ever. Now they'll know exactly how to position it.
#
# Together, we're creating a unified platform where insights inform creation, and creation is validated by performance data. That's a competitive advantage no single competitor can easily replicate.
#
# For our investor community: this acquisition positions Adobe at the intersection of two massive market trends — the rise of AI-driven insights and the continued explosion in digital content creation.
#
# The integration ahead will be seamless, strategic, and deeply focused on customer value.
#
# Are your tools working in isolation, or in perfect harmony?
#
# #Adobe #Semrush #MarketTech #DigitalMarketing #FutureOfWork
#
# 3. We're solving marketing's biggest bottleneck: the creativity-to-performance gap.
#
# Marketers have always faced an uncomfortable truth: great creative doesn't guarantee great results. Data might tell you what's working, but it rarely tells you why. Until now.
#
# Adobe's acquisition of Semrush brings together the tools that matter most. On one side, Adobe's creative suite — used by millions to bring ideas to life. On the other, Semrush's unmatched visibility into market trends, competitor moves, and search behavior.
#
# **The opportunity before us:**
#
# What if every creative decision was informed by real market intelligence? What if every optimization was guided by competitive insight? What if your entire marketing engine operated as one integrated system instead of a collection of disconnected platforms?
#
# That's the future we're building.
#
# This acquisition reflects our commitment to delivering exceptional returns through strategic growth. Semrush's proven business model, strong margins, and loyal customer base align perfectly with Adobe's growth trajectory. We're adding $150M+ in ARR to our portfolio while opening entirely new growth vectors.
#
# For customers: expect deeper integrations, more powerful insights, and a seamless experience across the entire marketing lifecycle.
#
# What would you accomplish if creativity and data were finally on the same team?
#
# #Adobe #Semrush #MarketingInnovation #DigitalStrategy #Growth
#
# 4. The era of fragmented marketing stacks is over.
#
# At Adobe, we believe the future belongs to platforms that break down silos. Today's announcement proves we mean it.
#
# Semrush represents far more than a transaction — it's our statement about where marketing is headed. Brands can no longer afford to operate with separate tools for creation, optimization, and measurement. The winners will be those with unified platforms that turn insights into impact.
#
# **Why now? Why Semrush?**
#
# The market has spoken. Semrush's explosive growth, global customer base, and category leadership demonstrate that brands desper

# %%
filled_prompt = instagram_template.format(
    brand_name="Adobe",
    topic="CEO Shantanu Narayen announcing retirement after 17 years of leadership",
    tone="warm, celebratory, human — honor the legacy while exciting the community about Adobe's bold future ahead"
)
response = llm.invoke([HumanMessage(content=filled_prompt)])
print("INSTAGRAM POSTS:")
print(response.content)
# Out:
# INSTAGRAM POSTS:
# 1. 17 years. One visionary. Countless masterpieces created by millions of creators worldwide. 🎨
#
# Today we celebrate Shantanu Narayen's incredible journey as Adobe's CEO—a leader who didn't just build a company, he empowered a global creative movement. From transforming how we design to democratizing creativity itself, Shantanu's legacy lives in every project you've poured your heart into. 💙
#
# His leadership planted seeds that continue to grow, and now? Adobe is ready to sprint into its next chapter with fresh energy, bold innovation, and the same creative spirit that defines us all. This isn't an ending—it's a launchpad for what's possible next. 🚀
#
# What's your favorite Adobe moment? Drop it in the comments—let's celebrate the tools and community that make creation possible. 👇✨
#
# #AdobeLife #CreativeEvolution #ShantanuNarayen #AdobeFuture #CreatorsUnited #DesignCommunity #AdobeFamily #NextChapter
#
# 2. A leader who saw potential in pixels, possibilities in problems, and purpose in creativity. 🌟
#
# Shantanu Narayen is stepping back from the CEO role after 17 transformative years—and wow, what a legacy. Under his vision, Adobe became more than software. It became the heartbeat of the creative world. The platform where your wildest ideas come to life. The tool that turns "what if" into "why not." 🎬✨
#
# From revolutionary product innovations to building a community of millions, Shantanu's fingerprints are all over the work you love creating. He believed in you before you believed in yourself. And that belief shaped everything Adobe is today.
#
# Ready for the next adventure? Adobe's future is in brilliant hands, and honestly? The best is yet to come. 💪
#
# Tag someone whose work wouldn't exist without Adobe. Let's celebrate creators like you. 👇
#
# #AdobeLeadership #CreativeJourney #AdobeCommunity #ShantanuNarayen #DesignPower #CreativeTools #AdobeInnovation #LeadershipLegacy #CreatorEconomy
#
# 3. Sometimes the greatest gift a leader leaves behind isn't what they built—it's what they inspired others to build. 🌱
#
# Today, we honor Shantanu Narayen's 17-year journey as Adobe's CEO. A journey marked by unwavering belief in creators, bold bets on innovation, and a commitment to making world-class creative tools accessible to everyone. 🎨💡
#
# From AI-powered creativity to cloud collaboration that changed how teams work, Shantanu's vision reimagined what's possible. But more than that? He believed in *you*—the student, the dreamer, the visionary who needed the right tools to bring ideas to life.
#
# His leadership created space for creativity to flourish. And now, Adobe stands ready to write the next story—one filled with possibility, innovation, and endless creative potential.
#
# Share a moment when Adobe tools helped you create something you're proud of. We'd love to celebrate your wins. 👇💫
#
# #AdobeFamily #CreativeVision #LeadershipMatters #ShantanuNarayen #DesignCommunity #AdobeTools #CreatorLife #InnovationLeads #AdobeFuture
#
# 4. The most powerful creations aren't made by one person—they're enabled by someone who believed in millions. 🌍
#
# After 17 years leading Adobe, Shantanu Narayen is passing the torch—and what a torch it is. Burning bright with possibility, innovation, and the unmistakable mark of a leader who understood that the best technology gets out of the way so *you* can shine. ✨
#
# Whether you're a designer, filmmaker, photographer, or creative risk-taker, Shantanu's impact is in your work. It's in the projects you've shipped, the collaborations that happened seamlessly in the cloud, and the AI features that gave you superpowers. His leadership created the foundation for your creative freedom.
#
# This is a moment to celebrate how far we've come together. And to get excited about what's next—because Adobe's future is bolder, faster, and more human-centered than ever.
#
# What's your favorite Adobe creation story? Jump into the comments and let's celebrate the magic. 🎬

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("thedevastator/tweets-and-user-engagement")

print("Path to dataset files:", path)
# Out:
# Downloading to /root/.cache/kagglehub/datasets/thedevastator/tweets-and-user-engagement/2.archive...
# 100%|██████████| 8.70M/8.70M [00:00<00:00, 247MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/thedevastator/tweets-and-user-engagement/versions/2

# %%
import requests

github_file_url = "YOUR_GITHUB_RAW_URL_HERE" # Replace with the raw URL of your dataset file on GitHub

# Extract filename from URL
filename = github_file_url.split('/')[-1]

try:
    response = requests.get(github_file_url)
    response.raise_for_status() # Raise an exception for HTTP errors

    with open(filename, 'wb') as f:
        f.write(response.content)

    print(f"Dataset '{filename}' downloaded successfully!")
except requests.exceptions.RequestException as e:
    print(f"Error downloading file: {e}")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Error downloading file: Invalid URL 'YOUR_GITHUB_RAW_URL_HERE': No scheme supplied. Perhaps you meant https://YOUR_GITHUB_RAW_URL_HERE?

# %%
import os

# Paste your token value here between the quotes
KAGGLE_TOKEN = "KGAT_bb4ee1763840e8cec48410422b69e997"

# Set up the environment variable
os.environ['KAGGLE_API_TOKEN'] = KAGGLE_TOKEN

# Install kaggle
# !pip install kaggle -q

print("Kaggle setup done!")
# Out:
# Kaggle setup done!

# %%
# Download the dataset
# !kaggle datasets download -d thedevastator/tweets-and-user-engagement --unzip

# Check what got downloaded
import os
print(os.listdir('.'))
# Out:
# Dataset URL: https://www.kaggle.com/datasets/thedevastator/tweets-and-user-engagement
# License(s): other
# Downloading tweets-and-user-engagement.zip to /content
# 100% 8.70M/8.70M [00:00<00:00, 243MB/s]
#
# ['.config', 'Twitterdatainsheets.csv', 'sample_data']

# %% [markdown]
# For good few-shot examples we want posts from 3-4 different brand styles:
#
# | Style | Example Brand | Why |
# | -------- | -------- | -------- |
# | Consumer/Lifestyle | Starbucks, Nike | Casual, emotional, visual |
# | B2B/Tech | AWS, Adobe | Professional, feature-focused |
# | News/Corporate | BBC, Reuters | Informational, factual |
# | Startup/Energetic | Spotify, Duolingo | Fun, bold, personality-driven |

# %% [markdown]
# # Few-Shot Examples for Social Media Agent
# ## Collected: May 2026 | Sources: Nike (Twitter), Adobe (LinkedIn), National Geographic (Instagram)
#
# ---
#
# ## Twitter Examples (Source: @Nike)
#
# **Example 1 — Athlete/Event Celebration:**
# "When you're this fast, you don't ask for permission.
# Jutta Leerdam breaks the Olympic record in the Speed Skating 1000m
# and wins her first Gold. #MilanoCortina2026 #Olympics"
#
# **Example 2 — Product Launch:**
# "Mute the gallery. Introducing Nike Powerbeats Pro 2, the ultimate
# fitness earbuds. The first-ever Beats x Nike collab — where premium
# sound meets unbeatable stability. No advice required.
# Launching March 20th at 9am PST at apple.com, nike.com,
# and select Apple stores globally."
#
# **Example 3 — Motivational/Quote:**
# "There's no failure in sports. It's steps to success." - @Giannis_An34
# Regardless of the outcome, there's always a reward ahead.
# #AlwaysForward"
#
# ---
#
# ## LinkedIn Examples (Source: Adobe)
#
# **Example 1 — Thought Leadership/Research:**
# "Creative teams are under pressure to deliver more content across
# more channels than ever before. Many are turning to AI to handle
# production tasks like resizing, versioning, and early-stage ideation,
# so they can spend more time refining concepts and craft.
# Adobe's latest research breaks down how this shift is changing
# the way we do creative work.
# Learn more: https://adobe.ly/3QJAEcK"
#
# **Example 2 — Corporate Announcement:**
# "The way brands are discovered is changing fast. Today, Adobe
# completed its acquisition of Semrush, expanding how businesses
# show up, get found, and drive growth in an AI-first world.
# The shift is already here. AI-driven traffic to U.S. retail sites
# is up 269% year over year, yet most businesses still have significant
# gaps in how they appear across AI surfaces. Visibility is no longer
# just about ranking. It is about relevance, presence, and performance
# across every surface where decisions are made.
# Together, as part of Adobe CX Enterprise, Adobe and Semrush are
# helping businesses close that gap across SEO, generative engine
# optimization (GEO), and agentic search optimization (ASO), with
# deeper insights, stronger intelligence, and more connected customer
# experiences. We look forward to welcoming Semrush team members
# into Adobe. We can't wait to build what's next, together."
#
# **Example 3 — Community/Human Story:**
# "My greatest inspiration came from being raised by a self-made
# single mom who showed us strength and resilience."
# From drawing at a young age to now utilizing Adobe tools to bridge
# the gap between art and business, Alexandra Yvette continues to
# create and share her talents with the world this Women's History Month."
#
# ---
#
# ## Instagram Examples (Source: @NatGeo)
#
# **Example 1 — Wildlife/Action Story:**
# "This image was taken near Polán, Toledo province (Spain) last August
# (2025), from a tiny hide-out overlooking a small waterhole where
# lynxes occasionally come down to drink. It was an extremely hot
# afternoon, and a rabbit was very close to the water. Suddenly, a lynx
# appeared silently, but the rabbit noticed it at the very last second.
# In a desperate attempt to escape, it launched itself into the water
# and then made an incredible leap over the lynx's paw. I couldn't
# believe what I was witnessing. For a brief moment, the rabbit actually
# escaped, and then the chase began. It lasted only a couple of minutes,
# but it felt endless. I've been photographing Iberian lynxes for more
# than five years, and this was the first time in my life I was able to
# witness and document a complete hunting sequence.
# Photo by @alexandrovich_yo from our @natgeoyourshot community."
#
# **Example 2 — Landscape/Philosophical:**
# "From Punta Helbronner, 11,370 feet (3,466 meters) above sea level
# on the Italian side of Mont Blanc in the Alps, my guide walks out
# across the snow toward Dent du Géant, the Giant's Tooth, illuminated
# only by the light of my drone during a long exposure.
# In images like this, I'm interested in how a small change in the light
# can shift the scale of a landscape, briefly turning a lone figure into
# a point of orientation within something far larger and older.
# In the blue hour, the mountain held its shape with a seemingly
# absolute stillness, while that moving light traced a human presence
# across the snow for just a few seconds.
# Photos by @reuben"
#
# **Example 3 — Milestone/Achievement:**
# "Barcelona's Sagrada Família has reached a new milestone. With the
# cross now installed atop its central Jesus tower, the basilica stands
# more than 560 feet (170m) — surpassing Germany's Ulm Minster as
# the world's tallest church. Discover how architects used modern tools
# and building techniques to bring Antoni Gaudí's original design to
# life more than 140 years after he began construction at the link in bio.
# Photographs by Nuria Puentes, National Geographic-España"
#
# ---
#
# ## Summary Table
#
# | Platform | Example 1 | Example 2 | Example 3 |
# |---|---|---|---|
# | Twitter | Athlete/Event | Product Launch | Motivational Quote |
# | LinkedIn | Thought Leadership | Corporate Announcement | Human Story |
# | Instagram | Wildlife Drama | Landscape Poetry | Milestone/Achievement |
#
# ## Why These Examples Were Chosen
# - **Variety of formats** — each example covers a different post type
# - **Real posts from real brands** — not fabricated, actual published content
# - **High engagement posts** — sourced from top brand pages
# - **Platform appropriate** — tone, length and structure match each platform's norms
# - **Text stands alone** — captions work without needing to see the image
#
# ---
# *Note: For future iterations, automate example selection by pulling
# top performing posts from brand analytics APIs ranked by real
# engagement data.*

# %%
# Few-shot examples for each platform
twitter_examples = """
EXAMPLE 1 (Athlete/Event Celebration - Nike):
"When you're this fast, you don't ask for permission. Jutta Leerdam
breaks the Olympic record in the Speed Skating 1000m and wins her
first Gold. #MilanoCortina2026 #Olympics"

EXAMPLE 2 (Product Launch - Nike):
"Mute the gallery. Introducing Nike Powerbeats Pro 2, the ultimate
fitness earbuds. The first-ever Beats x Nike collab — where premium
sound meets unbeatable stability. No advice required.
Launching March 20th at 9am PST."

EXAMPLE 3 (Motivational/Quote - Nike):
"There's no failure in sports. It's steps to success." - @Giannis_An34
Regardless of the outcome, there's always a reward ahead. #AlwaysForward
"""

linkedin_examples = """
EXAMPLE 1 (Thought Leadership - Adobe):
"Creative teams are under pressure to deliver more content across more
channels than ever before. Many are turning to AI to handle production
tasks like resizing, versioning, and early-stage ideation, so they can
spend more time refining concepts and craft. Adobe's latest research
breaks down how this shift is changing the way we do creative work."

EXAMPLE 2 (Corporate Announcement - Adobe):
"The way brands are discovered is changing fast. Today, Adobe completed
its acquisition of Semrush, expanding how businesses show up, get found,
and drive growth in an AI-first world. The shift is already here.
AI-driven traffic to U.S. retail sites is up 269% year over year, yet
most businesses still have significant gaps in how they appear across
AI surfaces. Visibility is no longer just about ranking. It is about
relevance, presence, and performance across every surface where
decisions are made."

EXAMPLE 3 (Community/Human Story - Adobe):
"My greatest inspiration came from being raised by a self-made single
mom who showed us strength and resilience. From drawing at a young age
to now utilizing Adobe tools to bridge the gap between art and business,
Alexandra Yvette continues to create and share her talents with the
world this Women's History Month."
"""

instagram_examples = """
EXAMPLE 1 (Wildlife/Action Story - NatGeo):
"This image was taken near Polán, Toledo province (Spain) last August,
from a tiny hide-out overlooking a small waterhole where lynxes
occasionally come down to drink. It was an extremely hot afternoon,
and a rabbit was very close to the water. Suddenly, a lynx appeared
silently, but the rabbit noticed it at the very last second. In a
desperate attempt to escape, it launched itself into the water and
then made an incredible leap over the lynx's paw. I couldn't believe
what I was witnessing. For a brief moment, the rabbit actually escaped,
and then the chase began. I've been photographing Iberian lynxes for
more than five years, and this was the first time I was able to witness
and document a complete hunting sequence.
Photo by @alexandrovich_yo from our @natgeoyourshot community."

EXAMPLE 2 (Landscape/Philosophical - NatGeo):
"From Punta Helbronner, 11,370 feet above sea level on the Italian
side of Mont Blanc in the Alps, my guide walks out across the snow
toward Dent du Géant, the Giant's Tooth, illuminated only by the
light of my drone during a long exposure. In images like this, I'm
interested in how a small change in the light can shift the scale of
a landscape, briefly turning a lone figure into a point of orientation
within something far larger and older. In the blue hour, the mountain
held its shape with a seemingly absolute stillness, while that moving
light traced a human presence across the snow for just a few seconds.
Photos by @reuben"

EXAMPLE 3 (Milestone/Achievement - NatGeo):
"Barcelona's Sagrada Família has reached a new milestone. With the
cross now installed atop its central Jesus tower, the basilica stands
more than 560 feet (170m) — surpassing Germany's Ulm Minster as the
world's tallest church. Discover how architects used modern tools and
building techniques to bring Antoni Gaudí's original design to life
more than 140 years after he began construction.
Photographs by Nuria Puentes, National Geographic-España"
"""

print("✅ Few-shot examples loaded!")
# Out:
# ✅ Few-shot examples loaded!

# %%
from langchain_core.prompts import PromptTemplate

# Twitter Few-Shot Template
twitter_fewshot_template = PromptTemplate(
    input_variables=["brand_name", "topic", "tone"],
    template="""
You are an expert social media content creator.

Your task is to write 5 distinct Twitter post variants for the brand {brand_name}.

TOPIC: {topic}
TONE: {tone}

TWITTER RULES:
- Maximum 280 characters per post
- Use 2-3 relevant hashtags per post
- Keep language punchy and direct
- Include a call to action where natural

HERE ARE EXAMPLES OF HIGH PERFORMING TWITTER POSTS:
""" + twitter_examples + """

Now write 5 posts matching the same quality and style as the examples above.

OUTPUT FORMAT:
1. [post text] [hashtags]
2. [post text] [hashtags]
3. [post text] [hashtags]
4. [post text] [hashtags]
5. [post text] [hashtags]

Write only the posts. No explanations.
"""
)

# LinkedIn Few-Shot Template
linkedin_fewshot_template = PromptTemplate(
    input_variables=["brand_name", "topic", "tone"],
    template="""
You are an expert social media content creator specializing in professional content.

Your task is to write 5 distinct LinkedIn post variants for the brand {brand_name}.

TOPIC: {topic}
TONE: {tone}

LINKEDIN RULES:
- 150 to 300 words per post
- Start with a strong hook — first line must stop the scroll
- Use professional but human language
- Break text into short paragraphs for readability
- End with a thought provoking question or clear call to action
- Use 3-5 relevant hashtags at the end
- No excessive emojis — maximum 2 per post

HERE ARE EXAMPLES OF HIGH PERFORMING LINKEDIN POSTS:
""" + linkedin_examples + """

Now write 5 posts matching the same quality and style as the examples above.

OUTPUT FORMAT:
1. [post text]
[hashtags]

2. [post text]
[hashtags]

Write only the posts. No explanations.
"""
)

# Instagram Few-Shot Template
instagram_fewshot_template = PromptTemplate(
    input_variables=["brand_name", "topic", "tone"],
    template="""
You are an expert social media content creator specializing in Instagram content.

Your task is to write 5 distinct Instagram caption variants for the brand {brand_name}.

TOPIC: {topic}
TONE: {tone}

INSTAGRAM RULES:
- Maximum 2200 characters per post
- First line MUST be a scroll-stopping hook
- Use storytelling and lifestyle language
- Use emojis throughout to add personality
- Write in a warm, relatable, visual style
- Include a clear call to action before the hashtags
- Use 5-10 relevant hashtags at the end

HERE ARE EXAMPLES OF HIGH PERFORMING INSTAGRAM CAPTIONS:
""" + instagram_examples + """

Now write 5 captions matching the same quality and style as the examples above.

OUTPUT FORMAT:
1. [hook line]
[caption body]
[call to action]
[hashtags]

2. [hook line]
[caption body]
[call to action]
[hashtags]

Write only the captions. No explanations.
"""
)

print("✅ Few-shot templates loaded for all 3 platforms!")
# Out:
# ✅ Few-shot templates loaded for all 3 platforms!

# %%
# Test all 3 few-shot templates with the same topic
test_topic = "Adobe's acquisition of Semrush"
test_brand = "Adobe"

# Twitter
twitter_filled = twitter_fewshot_template.format(
    brand_name=test_brand,
    topic=test_topic,
    tone="confident, forward looking, market leading"
)
twitter_response = llm.invoke([HumanMessage(content=twitter_filled)])
print("=" * 50)
print("TWITTER POSTS:")
print("=" * 50)
print(twitter_response.content)

# LinkedIn
linkedin_filled = linkedin_fewshot_template.format(
    brand_name=test_brand,
    topic=test_topic,
    tone="professional, strategic, reassuring to investors, forward looking"
)
linkedin_response = llm.invoke([HumanMessage(content=linkedin_filled)])
print("\n" + "=" * 50)
print("LINKEDIN POSTS:")
print("=" * 50)
print(linkedin_response.content)

# Instagram
instagram_filled = instagram_fewshot_template.format(
    brand_name=test_brand,
    topic=test_topic,
    tone="warm, celebratory, innovative, inspiring"
)
instagram_response = llm.invoke([HumanMessage(content=instagram_filled)])
print("\n" + "=" * 50)
print("INSTAGRAM POSTS:")
print("=" * 50)
print(instagram_response.content)
# Out:
# ==================================================
# TWITTER POSTS:
# ==================================================
# 1. We're acquiring Semrush. Together, we're building the ultimate platform where creativity meets intelligence. The future of digital marketing just got more powerful. #AdobeSemrush #CreativeCloud #MarketLeadership
#
# 2. Semrush joins Adobe. Two industry leaders unite to give you unprecedented insights + creative tools. Your competitive edge just got sharper. Experience the difference—explore what's next. #AdobeAcquisition #DigitalMarketing #Innovation
#
# 3. Game-changing move: Adobe acquires Semrush. Now creators and marketers get world-class SEO + design in one ecosystem. The era of connected creativity starts now. #AdobeSemrush #CreativeIntelligence #FutureReady
#
# 4. One platform. Infinite possibilities. Adobe + Semrush = unstoppable. We're redefining how brands create, market, and win. Join the revolution. #AdobeSemrush #CreativeCloud #MarketDominance
#
# 5. Semrush is now part of Adobe. Creators, marketers, leaders—your toolkit just leveled up. Intelligence meets imagination. Discover the combined power today. #AdobeAcquisition #ContentCreation #LeadingTheWay
#
# ==================================================
# LINKEDIN POSTS:
# ==================================================
# 1. Adobe just acquired Semrush—and this changes everything for how brands compete in 2024.
#
# For years, companies have operated in silos: creative teams building assets in one place, marketing teams optimizing visibility in another. This acquisition bridges that gap. Now, creators and marketers can work from a unified platform to not just produce great content, but ensure it performs where it matters most.
#
# The strategic play here? In an AI-driven world, visibility is a competitive advantage. Semrush's deep insights into search, content performance, and market positioning combine with Adobe's creative firepower. That means brands can ideate, create, optimize, and measure—all in one ecosystem.
#
# This isn't just about tools. It's about giving businesses the integrated intelligence they need to make faster, smarter decisions. For investors watching digital transformation unfold, this is Adobe doubling down on its core thesis: enabling creativity with data-driven strategy.
#
# The question isn't whether your brand needs both creative excellence and market visibility. It's whether you can afford not to have them working together.
#
# #Adobe #Semrush #DigitalMarketing #CreativeStrategy #MarketingTech
#
# ---
#
# 2. When a creative powerhouse meets a market intelligence leader, something remarkable happens. Adobe's acquisition of Semrush creates a new category in digital business software.
#
# Think about your workflow right now. You're likely using separate platforms to create content, analyze performance, understand search trends, and optimize for visibility. That fragmentation costs time, accuracy, and competitive advantage.
#
# With this acquisition, Adobe is solving a fundamental problem: the disconnect between what you create and how it performs in the real world. Creators get actionable insights. Marketers get creative speed. Leadership gets unified visibility into ROI.
#
# For investors, this move signals confidence in a thesis: the future belongs to platforms that close the gap between creativity and performance. Semrush brings 13+ years of SEO and market intelligence expertise. Adobe brings the world's leading creative tools.
#
# Together, they're positioned to serve the growing number of brands demanding integrated solutions—not tool sprawl.
#
# The next wave of competitive advantage won't come from choosing between being creative or data-driven. It'll come from doing both, seamlessly.
#
# #AdobeAcquisition #Semrush #IntegratedMarketing #MarketingTechnology #BusinessStrategy
#
# ---
#
# 3. Adobe's acquisition of Semrush isn't about adding another tool to the toolbox. It's about reimagining how modern businesses operate.
#
# The creative economy is accelerating. Content demands are multiplying. Meanwhile, visibility challenges are becoming more complex—especially as AI reshapes how customers discover brands. Most companies feel caught between two worlds: investing in creative excellence or market performance. They shouldn't have to choose.
#
# This acquisition represents a strategic bet on integration. When creators understand market demand in real-time, they make smarter content decisions. When marketers have immediate access to production capabilities, campaigns launch faster. When leadership sees unified metrics, strategy becomes clearer.
#
# For investors evaluating Adobe's long-term positioning, this move demonstrates a commitment to capturing a larger share of how businesses solve their most pressing challenge: reaching the right audience with resonant, optimized content.
#
# The integration of Semrush's market intelligence with Adobe's creative platform creates competitive moats that are difficult to replicate. This is about sustainable growth.
#
# What would your organization accomplish if creative teams and marketing teams operated from the same strategic foundation?
#
# #AdobeStrategy #DigitalTransformation #MarketingInnovation #CreativeEconomy #TechAcquisition
#
# ---
#
# 4. The acquisition of Semrush by Adobe signals a clear direction: the future of marketing is integrated, data-informed, and creative.
#
# For too long, the industry accepted fragmentation. Designers worked separately from strategists. Content creators operated independently from performance analysts. The result? Slower time-to-market, siloed insights, and missed opportunities.
#
# Adobe's move changes this equation. By combining world-class creative tools with Semrush's proven market intelligence platform, the company is creating an end-to-end solution for brands that need both creative excellence and measurable results.
#
# Here's what this means in practice: campaigns that are informed by real market data before they're even conceived. Content optimized for performance across every channel. Teams that speak the same language because they're working in the same platform.
#
# For investors, acquisitions of this caliber aren't just about revenue expansion—they're about building defensible positions in markets that are consolidating around integrated platforms. This is Adobe strengthening its mo
#
# ==================================================
# INSTAGRAM POSTS:
# ==================================================
# 1. When two creative powerhouses join forces, magic happens. ✨
#
# We're thrilled to announce that Adobe is welcoming Semrush into our family! 🎉 For years, creators and businesses have relied on Semrush's brilliant insights to amplify their digital presence. Now, imagine what becomes possible when you combine Semrush's industry-leading SEO and content intelligence with Adobe's creative tools. This isn't just an acquisition—it's a moment where strategy meets creativity, where data breathes life into ideas, and where your vision gets the superpowers it deserves. 🚀
#
# We're building a future where creators don't have to choose between craftsmanship and strategy. Where your brilliant designs are backed by brilliant insights. Where innovation knows no limits. 💡
#
# This is more than a business milestone—it's a promise to you that we're committed to breaking down barriers and building tools that help you create, optimize, and dominate your space.
#
# Ready to see what's next? Explore how this bold move reshapes the future of creative technology.
#
# #AdobeInnovates #SemrushJoinsAdobe #CreativeStrategy #DigitalCreativity #FutureOfCreative #AdobeCreativeCloud #MarketingInnovation
#
# 2. Plot twist: your favorite creative toolkit just got a strategic genius. 🧠✨
#
# Today, we're writing a new chapter in the Adobe story. Semrush—the platform trusted by millions to unlock digital growth—is now part of the Adobe family. 🎨 Think about it: what happens when world-class design tools meet industry-leading SEO intelligence? When your creative vision is powered by data-driven insights? When inspiration and strategy dance together in perfect harmony? 💫
#
# For creators, designers, and marketers, this is the moment you've been waiting for. No more switching between platforms. No more guessing games. Just pure, unbounded potential.
#
# We're not just acquiring a company; we're expanding what's possible for everyone who creates. 🌟
#
# Jump in and discover how Adobe + Semrush creates the ultimate creative ecosystem. Your next masterpiece is waiting.
#
# #AdobeCreativeCloud #SemrushAcquisition #CreativeEmpowerment #DesignMeetsData #MarketingTools #CreatorsUnite #InnovationInAction
#
# 3. This is what happens when innovation meets ambition. 🚀
#
# For nearly two decades, Semrush has been the trusted voice helping creators and marketers understand the digital landscape. Today, that voice joins Adobe's mission to empower billions to create and communicate. 💡 We're merging two visionary platforms because we believe the future belongs to those who can blend creativity with strategy—those who don't just make beautiful things, but make things that matter. ✨
#
# Imagine having the insights of Semrush woven directly into your creative workflow. Imagine designing campaigns that aren't just stunning, but strategically unstoppable. 🎯 This acquisition isn't about doing more with less—it's about unlocking what was never possible before.
#
# We're reimagining what creative tools can do. We're expanding possibilities. We're building toward a future where every creator has access to every insight they need to succeed. 🌍
#
# Be part of this journey. Experience how Adobe's creativity meets Semrush's intelligence.
#
# #AdobeAcquisition #SemrushPartnership #CreativeInnovation #DesignStrategy #FutureOfMarketing #EmowerCreators #AdobeVision
#
# 4. Some stories are about growth. This one is about transformation. 📖✨
#
# Today marks a beautiful moment: Semrush—a platform that's helped countless creators and businesses rise—is joining Adobe's ever-expanding universe of tools designed to unleash human creativity. 🌟 This isn't just business news. It's a celebration of what happens when two companies that deeply understand creators come together with a shared vision. 🎨
#
# For too long, creatives have juggled platforms, switched between dashboards, and lost momentum between tools. We're changing that. By bringing Semrush into the Adobe family, we're creating something unprecedented: a holistic ecosystem where your creativity is informed, your strategy is inspired, and your success is inevitable. 💪✨
#
# This merger represents our unwavering commitment to you—the makers, the dreamers, the builders. We're saying: you deserve tools as

# %%
from langchain_core.prompts import PromptTemplate
import json

json_template = PromptTemplate(
    input_variables=["brand_name", "topic", "tone", "platform"],
    template="""
You are an expert social media content creator.

Generate exactly 5 distinct social media post variants for the brand {brand_name}.

PLATFORM: {platform}
TOPIC: {topic}
TONE: {tone}

PLATFORM RULES:
- Twitter: maximum 280 characters, 2-3 hashtags, punchy and direct
- LinkedIn: 150-300 words, professional but human, 3-5 hashtags
- Instagram: storytelling style, 5-10 hashtags, strong opening hook

IMPORTANT: You must respond with ONLY a valid JSON array.
No explanations. No preamble. No markdown. Just the JSON.

Return exactly this structure:
[
  {{
    "variant_id": 1,
    "post_text": "the post content here",
    "hashtags": ["#hashtag1", "#hashtag2"],
    "tone": "describe the tone used",
    "suggested_posting_time": "best day and time to post",
    "platform": "{platform}"
  }},
  {{
    "variant_id": 2,
    "post_text": "the post content here",
    "hashtags": ["#hashtag1", "#hashtag2"],
    "tone": "describe the tone used",
    "suggested_posting_time": "best day and time to post",
    "platform": "{platform}"
  }},
  {{
    "variant_id": 3,
    "post_text": "the post content here",
    "hashtags": ["#hashtag1", "#hashtag2"],
    "tone": "describe the tone used",
    "suggested_posting_time": "best day and time to post",
    "platform": "{platform}"
  }},
  {{
    "variant_id": 4,
    "post_text": "the post content here",
    "hashtags": ["#hashtag1", "#hashtag2"],
    "tone": "describe the tone used",
    "suggested_posting_time": "best day and time to post",
    "platform": "{platform}"
  }},
  {{
    "variant_id": 5,
    "post_text": "the post content here",
    "hashtags": ["#hashtag1", "#hashtag2"],
    "tone": "describe the tone used",
    "suggested_posting_time": "best day and time to post",
    "platform": "{platform}"
  }}
]
"""
)

print("✅ JSON template loaded!")
# Out:
# ✅ JSON template loaded!

# %%
# Generate 5 variants as structured JSON
filled_json_prompt = json_template.format(
    brand_name="Adobe",
    topic="Adobe's acquisition of Semrush",
    tone="professional, strategic, reassuring to investors",
    platform="linkedin"
)

# Call Claude
response = llm.invoke([HumanMessage(content=filled_json_prompt)])

# Parse the JSON response
try:
    # Clean the response in case Claude adds any extra text
    response_text = response.content.strip()

    # Remove markdown code blocks if Claude adds them
    if response_text.startswith("```"):
        response_text = response_text.split("```")[1]
        if response_text.startswith("json"):
            response_text = response_text[4:]

    # Parse into Python list
    variants = json.loads(response_text)

    print("✅ JSON parsed successfully!")
    print(f"Number of variants: {len(variants)}")
    print("\n--- VARIANT 1 PREVIEW ---")
    print(f"Post text: {variants[0]['post_text'][:100]}...")
    print(f"Hashtags: {variants[0]['hashtags']}")
    print(f"Tone: {variants[0]['tone']}")
    print(f"Posting time: {variants[0]['suggested_posting_time']}")
    print(f"Platform: {variants[0]['platform']}")

except json.JSONDecodeError as e:
    print(f"❌ JSON parsing failed: {e}")
    print("Raw response:")
    print(response.content)
# Out:
# ✅ JSON parsed successfully!
# Number of variants: 5
#
# --- VARIANT 1 PREVIEW ---
# Post text: We're excited to announce Adobe's acquisition of Semrush, a strategic move that strengthens our posi...
# Hashtags: ['#Adobe', '#Acquisition', '#DigitalMarketing', '#StrategicGrowth', '#Innovation']
# Tone: professional, strategic, and reassuring
# Posting time: Tuesday 9:00 AM EST
# Platform: linkedin

# %%
# Print all 5 variants cleanly
for i, variant in enumerate(variants, 1):
    print(f"{'='*50}")
    print(f"VARIANT {i}")
    print(f"{'='*50}")
    print(f"Post Text:\n{variant['post_text']}")
    print(f"\nHashtags: {' '.join(variant['hashtags'])}")
    print(f"Tone: {variant['tone']}")
    print(f"Suggested Posting Time: {variant['suggested_posting_time']}")
    print(f"Platform: {variant['platform']}")
    print()
# Out:
# ==================================================
# VARIANT 1
# ==================================================
# Post Text:
# We're excited to announce Adobe's acquisition of Semrush, a strategic move that strengthens our position in the digital marketing and creative technology landscape. This acquisition enables us to integrate best-in-class SEO and content marketing capabilities into our ecosystem, delivering greater value to our customers. By combining Adobe's creative excellence with Semrush's powerful analytics and competitive intelligence tools, we're creating a more comprehensive solution for businesses navigating today's digital challenges. This investment reflects our commitment to innovation and customer success.
#
# Hashtags: #Adobe #Acquisition #DigitalMarketing #StrategicGrowth #Innovation
# Tone: professional, strategic, and reassuring
# Suggested Posting Time: Tuesday 9:00 AM EST
# Platform: linkedin
#
# ==================================================
# VARIANT 2
# ==================================================
# Post Text:
# Semrush joins Adobe. We're thrilled to welcome the talented Semrush team and their industry-leading platform to Adobe. This acquisition represents a pivotal moment in our strategy to empower marketers and creative professionals with integrated tools that span the entire customer journey. Together, we'll accelerate innovation in SEO, content marketing, and competitive intelligence while maintaining the reliability and performance our customers trust. For our investors, this signals our continued focus on strategic expansion and shareholder value creation in high-growth markets.
#
# Hashtags: #Adobe #Semrush #MarketingTechnology #CorporateStrategy #Investors
# Tone: professional, confident, and investor-focused
# Suggested Posting Time: Wednesday 10:00 AM EST
# Platform: linkedin
#
# ==================================================
# VARIANT 3
# ==================================================
# Post Text:
# Our acquisition of Semrush marks a significant milestone in Adobe's evolution. We're not just adding a platform—we're bringing together complementary strengths to serve the modern marketer. Semrush's expertise in SEO, content analytics, and market intelligence will integrate seamlessly with Adobe's creative suite, creating unprecedented value. This move underscores our disciplined M&A strategy and commitment to organic and inorganic growth. We're confident this acquisition will drive long-term value creation and position Adobe as the leading enterprise software company for digital transformation.
#
# Hashtags: #Adobe #MergersAndAcquisitions #EnterpriseSOFTWARE #DigitalTransformation #InvestorRelations
# Tone: professional, strategic, and reassuring to stakeholders
# Suggested Posting Time: Thursday 2:00 PM EST
# Platform: linkedin
#
# ==================================================
# VARIANT 4
# ==================================================
# Post Text:
# Why Semrush? Because our customers demanded it. Adobe's acquisition of Semrush reflects our unwavering commitment to listening to market needs and delivering integrated solutions that drive results. Semrush brings 15+ years of proven expertise in helping businesses understand and optimize their digital presence. By uniting these platforms, we're eliminating silos, reducing complexity, and enabling our customers to work more efficiently. For our investors, this demonstrates our ability to identify strategic opportunities that accelerate growth while strengthening our competitive moat.
#
# Hashtags: #Adobe #CustomerFocus #StrategicAcquisition #MarketLeadership #Synergy
# Tone: professional, customer-centric, and strategically reassuring
# Suggested Posting Time: Monday 11:00 AM EST
# Platform: linkedin
#
# ==================================================
# VARIANT 5
# ==================================================
# Post Text:
# Announcing Adobe's acquisition of Semrush—a transformative step forward. This strategic investment strengthens our portfolio and reaffirms our vision: to empower businesses with the tools they need to succeed in an increasingly competitive digital landscape. Semrush's platform complements Adobe's creative and collaboration capabilities, enabling us to serve marketing and creative teams with unmatched depth and breadth. We're committed to ensuring a smooth integration and maximizing value for all stakeholders. This acquisition exemplifies our balanced approach to growth and shareholder returns.
#
# Hashtags: #Adobe #Semrush #Acquisition #DigitalLeadership #CorporateGrowth
# Tone: professional, reassuring, and forward-looking
# Suggested Posting Time: Tuesday 10:30 AM EST
# Platform: linkedin
